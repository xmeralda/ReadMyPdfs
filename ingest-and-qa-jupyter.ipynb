# %% [markdown]
# # Embed multiple PDFs and query with OpenAI API

# %% [markdown]
# This Jupyter Notebook takes us through step by step how to load, parse, encode, and embed PDF files and then how to query them as a corpus using OpenAI APIs.

# %%
# You can run these one at a time to confirm you have the libraries that are needed in the block below. 
# Just take away the "#" and execute the cell.

#pip install PyPDF4
#pip install langchain
#pip install python-dotenv
#pip install pdfplumber

# %%
import pdfplumber
import PyPDF4
import re
import os
import sys
from typing import Callable, List, Tuple, Dict

from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain
from langchain.schema import HumanMessage, AIMessage

from dotenv import load_dotenv

# %%
# You will need to switch out this API key with your own. This one has been deleted.
# platform.openai.com
os.environ["OPENAI_API_KEY"] = "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"

# %% [markdown]
# ## Steps:
# 1. Get file paths of the PDFs
# 2. Parse the PDFs into pages with page numbers
# 3. Clean up the text
# 4. Create text chunks from each page, preserving page number and metadata as well as chunk number
# 5. Generate embeddings from the chunks
# 6. Store the embeddings so they can be accessed by an AI API
# 7. Enter into Q&A with the AI API

# %% [markdown]
# ### Step 1. Get file paths of the PDFs

# %%
def get_file_paths_and_names(directory):
    """
    Finds all the file names and paths within a directory
    
    """
    file_paths = [os.path.join(directory, f) for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    file_names = [os.path.splitext(f)[0] for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    return file_paths, file_names

# %%
# Step 0: Get file paths of all PDFs
data_directory = "/Users/esme/Downloads/Project/src/data"
file_paths, file_names = get_file_paths_and_names(data_directory)

# Note: You may need to define data_directory as an entire file path depending on your IDE.
    # For VSCode, we just need "data/"
file_paths
# Out:
# ['/Users/esme/Downloads/Project/src/data/marijuana.pdf',
#  '/Users/esme/Downloads/Project/src/data/fake_helicopter_incidents.csv']

# %% [markdown]
# For Steps 2-4, we'll first do it on just one of the pdfs so we can output some of the steps as we go and see how things look. Once we have a feel for what we're doing, we'll execute script that does the steps on each of the pdfs in our directory all at once.

# %% [markdown]
# ### Step 2. Parse the PDFs into pages with page numbers

# %%
def parse_pdf(file_path: str) -> Tuple[List[Tuple[int, str]], Dict[str, str]]:
    """
    Extracts the title and text from each page of the PDF.

    :param file_path: The path to the PDF file.
    :return: A tuple containing the title and a list of tuples with page numbers and extracted text.
    """
    if not os.path.isfile(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")

    metadata = extract_metadata_from_pdf(file_path)
    pages = extract_pages_from_pdf(file_path)

    return pages, metadata

# %%
def extract_metadata_from_pdf(file_path: str) -> dict:
    '''
    Extracts the metadata from a PDF.

    :param file_path: The path to the PDF file.
    :return: A dictionary of metadata types as keys and corresponding pdf information as values
    '''
    with open(file_path, "rb") as pdf_file:
        reader = PyPDF4.PdfFileReader(pdf_file)
        metadata = reader.getDocumentInfo()
        return {
            "title": metadata.get("/Title", "").strip(),
            "author": metadata.get("/Author", "").strip(),
            "creation_date": metadata.get("/CreationDate", "").strip(),
        }

# %%
def extract_pages_from_pdf(file_path: str) -> List[Tuple[int, str]]:
    """
    Extracts the text from each page of the PDF.

    :param file_path: The path to the PDF file.
    :return: A list of tuples containing the page number and the extracted text.
    """
    if not os.path.isfile(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")

    with pdfplumber.open(file_path) as pdf:
        pages = []
        for page_num, page in enumerate(pdf.pages):
            text = page.extract_text()
            if text.strip():  # Check if extracted text is not empty
                pages.append((page_num + 1, text))
    return pages

# %%
# Note that we call a function parse_pdf which itself calls two other functions: 
#  extract_metadata_from_pdf and extract_pages_from_pdf
raw_pages, metadata = parse_pdf(file_paths[0])# <-- Note we're only doing this on first document for now
# print(raw_pages)
print(metadata)
# Out:
# {'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}

# %%
# Checking on the output
type(raw_pages)
# Out:
# list

# %%
# We can see how many pages the first file has
len(raw_pages)
# Out:
# 12

# %%
# We can output these pages to see what information they each contain
for i in raw_pages:
    print(i)
# Out:
# (1, 'Stroke\nAHA SCIENTIFIC STATEMENT\nUse of Marijuana: Effect on Brain Health:\nA Scientific Statement From the American Heart\nAssociation\nThe American Academy of Neurology affirms the value of this statement as an educational tool for neurologists.\nFernando D. Testai, MD, PhD, Chair; Philip B. Gorelick, MD, MPH, Vice Chair; Hugo J. Aparicio, MD, MPH; Francesca M. Filbey, PhD;\nRaul Gonzalez, PhD; Rebecca F. Gottesman, MD, PhD; Miriam Melis, PhD; Mariann R. Piano, RN, PhD; Tiziana Rubino, PhD;\nSarah Y. Song, MD; on behalf of the American Heart Association Stroke Brain Health Science Subcommittee of the Stroke Council;\nCouncil on Arteriosclerosis, Thrombosis and Vascular Biology; Council on Cardiovascular and Stroke Nursing; Council on Lifestyle\nand Cardiometabolic Health; and Council on Peripheral Vascular Disease\nABSTRACT: Marijuana is perceived as a harmless drug, and its recreational use has gained popularity among young individuals.\nThe concentration of active ingredients in recreational formulations has gradually increased over time, and high-potency\nillicit cannabinomimetics have become available. Thus, the consumption of cannabis in the general population is rising.\nData from preclinical models demonstrate that cannabinoid receptors are expressed in high density in areas involved in\ncognition and behavior, particularly during periods of active neurodevelopment and maturation. In addition, growing evidence\nhighlights the role of endogenous cannabinoid pathways in the regulation of neurotransmitter release, synaptic plasticity, and\nneurodevelopment. In animal models, exogenous cannabinoids disrupt these important processes and lead to cognitive and Downloaded\nbehavioral abnormalities. These data correlate with the higher risk of cognitive impairment reported in some observational\nstudies done in humans. It is unclear whether the effect of cannabis on cognition reverts after abstinence. However, this\nevidence, along with the increased risk of stroke reported in marijuana users, raises concerns about its potential long-term\neffects on cognitive function. This scientific statement reviews the safety of cannabis use from the perspective of brain from\nhealth, describes mechanistically how cannabis may cause cognitive dysfunction, and advocates for a more informed health\nhttp://ahajournals.org\ncare worker and consumer about the potential for cannabis to adversely affect the brain.\nKey Words: AHA Scientific Statements ◼ brain ◼ cannabis ◼ cognition ◼ marijuana ◼ stroke\nby\nMarijuana, or cannabis, was considered an illicit drug for 11% in 2002 to 18% in 2019.3 The use of marijuana\non\ndecades. However, in many parts of the world, can- has gained popularity, particularly among adolescents and July\nnabis has been legalized for medical use or decrimi- young adults, with ≈36% of 12th graders and 43% of col-\n7,\nnalized for recreational or medicinal applications. This shift lege students reporting having used it in the past year.4 In 2023\nin attitude has resulted in a rapid increase in its use. It has parallel, evidence suggests that the potency of cannabis\nbeen estimated that ≈183 million people in the world used products in the United States, measured by the concentra-\nmarijuana in 20141 and that 22 million met criteria for can- tion of the primary psychoactive constituent of marijuana,\nnabis use disorder in 2016.2 In addition, according to the Δ9-tetrahydrocannabinol (THC), has gradually increased\n2002 to 2019 National Survey on Drug Use and Health, from ≈4% in 1995 to 15% in 2018.5\nthe proportion of the US population >12 years of age who Cannabinoid receptors are expressed in high density\nused marijuana in the past year increased gradually from in areas of the brain involved in executive function and\nThe content is solely the responsibility of the authors and does not necessarily represent the official views of the National Institutes of Health.\n© 2022 American Heart Association, Inc.\nStroke is ...
# (2, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nmemory such as the hippocampus, amygdala, and pre- cells. In the periphery, CB1 localizes to sympathetic nerve\nfrontal cortex (PFC), particularly during periods of active terminals and sensory neurons. In the central nervous CLINICAL\nAND\nbrain development.6 Acute intoxication with cannabinoids system, it is expressed mainly in presynaptic membranes\ncan impair memory and behavioral inhibition.7 Cannabi- of excitatory and inhibitory neurons, where it regulates GUIDELINES\nSTATEMENTS\nnoids also regulate anxiety and can produce psycho- the vesicular release of dopamine, GABA, and glutamate.\nsis-like effects.6 Evidence shows that age at exposure In comparison, CB2 is expressed mainly in immune cells,\nmay influence the effect of cannabinoids on cognitive including microglia.9\nfunction. For example, the prenatal, perinatal, and ado- CBD is a nonpsychoactive cannabinoid that has anti-\nlescent periods may be particularly sensitive to these oxidant and anti-inflammatory properties. It is thought\ncompounds.8 Data obtained in preclinical models have that CBD exerts some of the beneficial effects that\nshown that cannabis and its associated signaling path- phytocannabinoids have in Dravet syndrome and Len-\nways regulate neurotransmission and play an active role nox-Gastaut syndrome. Furthermore, studies done in\nin key cerebral processes, including neuroinflammation, preclinical models suggest that CBD is beneficial in\nneurogenesis, neural migration, synaptic pruning, and Alzheimer disease, cerebral ischemia, multiple sclero-\nwhite matter development.6,9 Furthermore, experimental sis, and other neurologic disorders.9,14 The therapeutic\ndata show that cannabinoids can regulate the function- potential of CBD is being investigated in different clinical\ning of different cytochrome-P450 isoforms and uridine trials. Compared with THC, CBD signals through differ-\n5′-diphospho-glucuronosyltransferases. Thus, there is ent pathways but does not activate CB1 and CB2. At low\na potential risk for drug-to-drug interactions with medi- concentration, CBD blocks the orphan G-protein–cou-\ncations commonly used by the elderly such as warfarin, pled receptor-55, the equilibrative nucleoside transporter\nantiarrhythmic agents, sedatives, and anticonvulsants.10 1, and the transient receptor potential of melastatin type\nThese factors have raised concerns about the poten- 8 channel. It also activates the serotonin (5-hydroxytryp-\ntial effect of cannabis on cognitive vitality. The goal of tamine) 1A receptor, the transient receptor potential of\nthis scientific statement is to critically appraise the safety ankyrin type 1 channel, and α3 and α1 glycine receptors.\nof cannabis use from the perspective of brain health. At high concentration, CBD activates the nuclear peroxi-\nsome proliferator-activated receptor γ and the transient\nreceptor potential of vanilloid types 1 and 2.12,14\nCANNABIS AND ENDOCANNABINOIDS Several cannabinoids have received approval in dif-\nferent countries for the treatment of specific medical Downloaded\nAnandamide and 2-arachidonoyl-glycerol are endog-\nconditions. In addition, high-potency synthetic canna-\nenous bioactive lipids that activate 2 G-protein–coupled\nbimimetics such as Spice are available in the illegal mar-\nreceptors designated as cannabinoid receptor type 1\nket (Table 1).15–17\n(CB1) and 2 (CB2). These lipids, called endocannabi- from\nnoids, are not stored in vesicles but are synthesized on\nhttp://ahajournals.org\ndemand. The system formed by the cannabinoid recep- NEUROBIOLOGICAL ACTIONS OF\ntors CB1 and CB2, endogenous ligands, and enzymes\nCANNABIS IN ANIMAL MODELS\ninvolved in their production and degradation is known as\nthe endocannabinoid system (ECS). A detailed descrip- Molecular and cellular mechanisms underlying the\ntion of the composition and regulation of the ECS is effects of cannabis on the developing brain are in ...
# (3, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nTable 1. Synthetic and Semisynthetic Cannabinoids CB1 receptors located on GABAergic interneurons,\nwhich represent nearly three-quarters of the brain CB1 STNEMETATS\nCannabinoid Active SENILEDIUG\ntype ingredient Indication receptors, and astrocytes, resulting in the release of\nhippocampal glutamate. Concomitantly, THC affects\nMedical15,16\nthe transmission of other neurotransmitters involved\nCesamet Nabilone Treatment of refractory cancer che-\n(synthetic THC motherapy–associated nausea and in the modulation of memory such as acetylcholine, LACINILC\nDNA\nanalog) vomiting*† adenosine, and serotonin.19,20 Furthermore, THC activa-\nMarinol (pill) Dronabinol (syn- Anorexia with weight loss in patients tion of CB1 receptors present on mitochondria leads to\nthetic THC) with AIDS or cancer*† decreased cellular respiration and ATP supply.19 ATP is\nSyndros Dronabinol (syn- Treatment of refractory cancer che- fundamental in maintaining and regulating neurotrans-\n(solution) thetic THC) motherapy–associated nausea and\nmission, and its reduction might contribute to THC-\nvomiting*†\ninduced cognitive deficits.\nEpidiolex Purified CBD Seizures associated with Lennox-\nGastaut syndrome and Dravet syn- Repeated exposure to cannabis, especially during\ndrome in patients >1 y of age* the adolescent developmental period, may be especially\nSeizures associated with tuberous scle- harmful to brain health and cause structural, molecular,\nrosis complex in patients >1 y of age*\nand functional alterations of brain circuits, particularly in\nSativex Nabiximols Adjunctive therapy for symptomatic the PFC and hippocampus.8,21,22 Long-term THC expo-\n(extract of treatment of refractory spasticity in\nTHC, CBD, adult patients with multiple sclerosis sure induces CB1 receptor downregulation and desen-\nand other minor indication† sitization that appear more intense and widespread after\ncannabinoids, Adjunctive treatment for symptomatic adolescent exposure as opposed to adulthood expo-\nterpenoids, and neuropathy in adult patients with mul-\nflavonoids) tiple sclerosis indication† sure.22 Data obtained in experimental models showed\nthat these effects could have implications for neurode-\nAdjunctive treatment for patients with\nadvanced cancer with refractory severe velopmental processes in which the ECS plays a role.\npain indication† Accordingly, long-term THC exposure during adoles-\nIllicit17 cence may disrupt dynamic changes occurring in gluta-\nK2, Spice, Originally synthesized to study the matergic and GABAergic systems, leading to excessive\nKronic, endocannabinoid system synaptic pruning (ie, loss of synaptic contacts), long-term\nKaos Bind cannabinoid receptors with high dysfunction in prefrontal excitatory/inhibitory balance,\naffinity and can cause hallucinations,\nand desynchronization of PFC neuronal networks, which Downloaded\nagitation, psychosis, short-term memory\nloss, seizures, coagulopathy, and myo- also dysregulate the mesolimbic dopaminergic pathway\ncardial infarction (Figure).23 These changes may represent the molecular\nCBD indicates cannabidiol; and THC, Δ9-tetrahydrocannabinol. underpinnings of cognitive deficits and altered emotional\nfrom\n*Approved by the US Food and Drug Administration. reactivity and social behavior observed long after ado-\n†Approved by the Health Products and Food Branch of Health Canada.\nlescent long-term THC exposure.22 Long-term changes http://ahajournals.org\nAnimal models have been used to examine the role of in brain functionality induced by THC exposure during\nthe ECS in the modulation of synaptic plasticity, a pro- adolescence might also arise from epigenetic modifica-\ncess that allows the brain to change and adapt to new tions with a marked reprogramming of the transcriptome,\ninformation.18 The ECS modulates synaptic plasticity by affecting mainly genes related to synaptic plasticity pro-\naffecting the strength of ...
# (4, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nCLINICAL\nAND\nGUIDELINES\nSTATEMENTS\nFigure. Effect of Δ9-tetrahydrocannabinol (THC) on different neurobiological processes.\nThe effect of THC on the brain constitutes a continuum throughout the lifetime of an individual. However, 2 windows of brain vulnerability have\nbeen identified in preclinical models. The colored boxes represent the different processes that have been demonstrated to be affected on\nexposure to THC during these sensitive developmental periods. PFC indicates prefrontal cortex.\nTHC in models of heavy cannabis use in middle adoles- information, have been observed in these neuroanatomic Downloaded\ncence. However, even lower doses may produce these areas (Figure).8,24,27–30 Aberrant glutamatergic function\nsame effects when administered earlier in adolescence.22 is a common hallmark, as indexed by changes in the\nexpression and function of ionotropic and metabotropic\nfrom\nreceptors and in dynamic regulation of glutamate lev-\nEFFECT OF PRENATAL EXPOSURE TO\nels by glutamate transporters at both synaptic cleft and http://ahajournals.org\nCANNABINOID AGONISTS\nextrasynaptic spaces. These changes depend largely on\nA recent study examined associations between prenatal the alterations of endocannabinoid signaling pathways\ncannabis exposure (PCE) and various indicators of mental caused by exogenous cannabinoids during development\nand neurocognitive health in a sample of 11 489 youth.26 and throughout ontogenesis (eg, neural proliferation,\nSelf-report of maternal cannabis use during pregnancy survival, directional axonal growth).8,24,27–30 Defects in\nwas associated with various adverse outcomes among ECS function also may account for the interneuronop- by\nyouth at 9 to 10 years of age, including poorer perfor- athy observed in many brain regions of PCE offspring, on\nJuly\nmance on tests of neurocognitive functioning and total a phenomenon often more prominent in female than in\nintracranial volumes, even after controlling for potential male animals.8,27–29 In the PFC, this persistent inhibitory 7,\n2023\nconfounders. Several reviews describe PCE sequelae circuit deficit also is associated with a delayed switch of\nin preclinical models.8,24,27–30 Here, we focus on mecha- GABA from its excitatory role early in development to a\nnistic insights inferred from animal studies recapitulat- classic inhibitory function exerted throughout the central\ning the neuropsychiatric features of clinical outcomes.31 nervous system later in life.8,29 This is particularly relevant\nThe detrimental effect of PCE on cognitive process- because the GABA switch represents a critical milestone\ning and emotional regulation of the progeny has been during neurodevelopment. Any alteration in the normal\nascribed to changes in intrinsic and synaptic properties and predictable temporal sequence of these periods\nand plasticity of cortical (eg, PFC), limbic (eg, amygdala, such as delays, stalls, or accelerations imposed by PCE\nhippocampus), and midbrain (eg, ventral tegmentum) may lead to perturbations of offspring cognitive process-\nregions. Changes in the balance of excitatory and inhibi- ing and emotional behavior.8,29\ntory input strength, along with alterations in how principal It was observed that marijuana use leads to dysregu-\nneurons and interneurons receive, integrate, and convey lation of monoaminergic pathways and stress response\nStroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396 April 2022 e179')
# (5, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nsystems.8,27–29 PCE hampers the maturation of mono- with more specific domains affected,36 albeit with smaller\namines, which also exert trophic actions on target neurons effect size compared with that found by Lovell et al.35 STNEMETATS\nSENILEDIUG\nand afferent terminals. This phenomenon may depend on Both lacked support for worse neurocognition in early\nepigenetic modifications and may be implicated in aber- adolescence in that neither found that age at onset of\nrant reward signaling. Furthermore, PCE is associated cannabis use influenced the association between expo-\nwith an endophenotype in the offspring, which displays sure and cognitive performance. LACINILC\nDNA\nprotracted dysregulation of stress responsivity that is In contrast to these meta-analyses, large longitu-\nnot explained by glucocorticoid levels. A susceptibility dinal studies provide stronger causal inferences by\nto acute and chronic stress is tied to many psychiatric examining change over time. In the CARDIA study\ndisorders, ranging from depressed mood and psycho- (Coronary Artery Risk Development in Young Adults),\nsis to substance use disorders and anxiety. A deeper 3385 participants 18 to 30 years of age were followed\nunderstanding of how PCE interferes with endocannabi- up longitudinally. Marijuana use was assessed peri-\nnoid signaling during neurodevelopment would allow us odically in the 25-year follow-up. In addition, cognitive\nto explore potential interventions aimed at restoring or assessment was completed 25 years after inception. In\nreprogramming the hierarchical progression of develop- this study, cumulative years of exposure to marijuana\nmental milestones. was associated with worse verbal memory (0.13 lower\nSD in the verbal memory test for each additional 5\nyears of exposure to marijuana).37 Longitudinal co-twin\nEFFECTS OF MARIJUANA USE ON HUMAN studies use a research design that additionally controls\nfor shared variance from genetic and environmental\nCOGNITION\nfactors. Two large longitudinal twin studies (n=3066)\nAcute intoxication from marijuana is associated with with neurocognitive measures collected before (at\nimpairment of working and episodic memory, behavioral 9–12 years of age) and after (17–20 years of age)\ndisinhibition, and impulsivity, which can affect perfor- cannabis exposure reported that declines in vocabulary\nmance in real-world activities.6 For example, a meta-anal- and general knowledge were associated with being a\nysis from 2016 showed that the odds of being involved cannabis user but not with amount of cannabis con-\nin a motor vehicle accident was increased 36% in can- sumed.38 Twins discordant for cannabis use showed no\nnabis users relative to nonusers.32 In addition, a crossover differences in IQ declines. Thus, differences were likely\nclinical trial published in 2020 investigated the effect of caused by shared risk factors. Using a similar design, Downloaded\ndifferent cannabis products in relation to on-road driving Meier et al39 reported that lower IQ predated canna-\ntests. The SD of lateral position, a measure of lane weav- bis use with no evidence of actual IQ declines among\ning, swerving, and overcorrection, was 20.29 cm at 40 to 1989 twins assessed at 5, 12, and 18 years of age.\nfrom\n100 minutes after inhalation of THC-dominant cannabis Ross et al40 evaluated other aspects of neurocogni-\nand 21.09 cm after inhalation of a mixture of THC and tion among 856 individual twins and reported only 1 http://ahajournals.org\nCBD. It is interesting to note that the SD of lateral posi- within-family effect of 70 tested. Specifically, frequency\ntion after inhalation of CBD-dominant cannabis was sim- of cannabis use at 17 years of age was associated with\nilar to that in the placebo group (18.21 cm versus 18.26 poorer executive functioning at 23 years of age, but\ncm).33 These observations illustrate the differential short- exec ...
# (6, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nlarge twin samples from the United States (n=474) and EFFECTS OF MARIJUANA USE ON\nAustralia (n=622), cannabis use was unrelated to vol- CLINICAL\nCEREBROVASCULAR RISK AND DISEASE\nAND\numes of the thalamus, caudate nucleus, putamen, palli-\ndum, hippocampus, amygdala, and nucleus accumbens.43 Cerebrovascular Risk Factors GUIDELINES\nSTATEMENTS\nA multisite study of cortical surface measures (n=262) Similar to the literature linking marijuana use with cardio-\nreported no difference in cortical thickness, surface area, vascular outcomes,10 evidence that marijuana consump-\nand gyrification index in cannabis users versus nonus- tion increases the prevalence of specific cerebrovascular\ners, in cannabis dependence versus nondependence risk factors and disease is limited by a preponderance\nversus nonusers, and in early adolescent versus late of observational studies, cross-sectional studies, case\nadolescent onset of cannabis use versus nonuse.44 Thus, reports, and case series prone to potential publication\nbrain structural abnormalities related to cannabis use are and other biases. Postulated adverse effects of mari-\ninconsistent. juana use may include sympathetic nervous system acti-\nFunctional MRI studies report more robust effects, vation, blood pressure changes, platelet activation, and\nparticularly after prolonged cannabis use. A meta-analy- electrophysiological effects.50–52 Concomitant tobacco\nsis of task-based functional MRI studies in current adult smoking and other substance use and abuse possibly\nand adolescent users found abnormalities in activation contribute to these effects, which may be short term and\nin both age groups. Relative to nonusing control sub- have been studied mostly in low-risk populations such\njects, adult cannabis users had greater brain activation as younger adults. These factors may explain why many\nin the superior (seed-based d mapping [SDM-Z], 1.561; longitudinal studies linking marijuana use and cardiovas-\nP<0.002) and posterior (SDM-Z, 1.479; P<0.003) trans- cular or metabolic risk factors have been negative after\nverse temporal and inferior frontal gyri (SDM-Z, 1.568; multivariable adjustment for unhealthy behaviors such as\nP<0.002) and less activation in the striatum (SDM-Z, diet and tobacco smoking.53–55\n−1.843; P<0.001), insula (SDM-Z, −1.637; P<0.001), Hypertension, in particular, is an important risk factor\nand middle frontal gyrus across different tasks. Adoles- for ischemic stroke, hemorrhagic stroke, and subarach-\ncent cannabis users also had greater activation in the noid hemorrhage. With marijuana use, the most common\ninferior parietal gyrus (SDM-Z, 1.06; P<0.001) and puta- acute reaction in humans is a decrease in blood pressure\nmen (SDM-Z, 1.008; P<0.001) compared with nonusers resulting from cannabinoid effects on the vasculature and\nacross various tasks, suggesting compensatory neuro- autonomic nervous system.52 Despite this physiological\nadaptive mechanisms.45 These functional abnormalities reaction, limited studies using the National Health and Downloaded\npersist despite cessation of cannabis use and beyond Nutrition Examination Survey showed a modest asso-\nthe period when THC metabolites are detectable. A ciation of recent cannabis use with higher systolic blood\nmeta-analysis of the same adolescent studies found that pressure and higher prevalence of hypertension among\nfrom\n>25-day abstinent adolescent cannabis users exhibited current users 30 to 59 years of age.56 Heavy users,\ngreater activation in the right inferior frontal gyrus in defined as use of marijuana or hashish in >20 of the http://ahajournals.org\naddition to other areas relevant for executive functioning past 30 days, had higher odds of abnormal blood pres-\nand self-regulatory mechanisms.46 sure compared with never-users. Although this difference\nSeveral recent studies examined cannabis effects in remained statistic ...
# (7, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nthe Coronary Artery Risk Development in Young Adults that when no cannabis use was compared with heavy\nstudy, cumulative or recent marijuana use was not asso- cannabis use in the past year, cannabis use was associ- STNEMETATS\nSENILEDIUG\nciated with coronary heart disease, stroke, or cardiovas- ated with an increased risk for the occurrence of nonfatal\ncular disease mortality.61 This finding contrasts with a stroke and transient ischemic attack.70 Similarly, another\npopulation-based, multi-institutional database study that study found that recent (within the past 30 days) and\nobserved an increased risk of 3-year cumulative inci- frequent (>10 d/mo) cannabis use was associated with LACINILC\nDNA\ndence of MI among marijuana users compared with con- increased risk for the occurrence of stroke compared\ntrol subjects (1.37% vs 0.54%; relative risk, 2.54 [95% with nonuse, whereas less frequent cannabis use (≤10\nCI, 2.45–2.61]).62 d/mo or less than weekly in the past year) was not asso-\nSimilarly, marijuana use appears to be a trigger for AF. ciated with increased risk.69,70\nData from the Nationwide Inpatient Sample show that the Using several International Classification of Diseases,\npercentage of individuals with cannabis use disorder dis- Ninth Revision, Clinical Modification codes for marijuana use,\ncharged in the postlegalization period (2010–2014) with a Nationwide Inpatient Sample study found that cannabis\nthe diagnosis of arrhythmia increased 31%.63 However, in use among men and women hospitalized between 2004\na study of patients hospitalized for heart failure, marijuana and 2011 was associated with a 17% increased relative risk\nusers had a reduced odds of AF compared with nonusers for acute ischemic stroke in a multivariable-adjusted analy-\n(adjusted odds ratio, 0.87 [95% CI, 0.77–0.98]).50 Simul- sis. Concomitant use of tobacco with cannabis increased\ntaneous use of cocaine, stimulants, and other drugs may the risk to 31%.71 Similarly, a separate study using the\nbe responsible for observations of AF among marijuana Nationwide Inpatient Sample but between 2009 and 2010\nusers, although this remains to be fully studied outside of observed a higher odds of stroke among cannabis users\nobservational and cross-sectional reports. (odds ratio, 1.24 [95% CI, 1.14–1.34]).72 In contrast, inves-\ntigators using electronic health record data from patients\nadmitted to a single center between 2015 and 2017 found\nRisk of Stroke and Transient Ischemic Attack\nthat testing positive for cannabis use was not associated\nSeveral case reports and case series mostly in young with the risk of ischemic stroke compared with testing\nindividuals suggest a relationship between recent and negative, even after adjustment for numerous confounders,\nheavy cannabis use and risk of stroke.64–66 In contrast, including age, cigarette smoking, and comorbidities.73\nand as reviewed below, findings among case-control There may be certain populations or scenarios in which\nstudies,67 population-based studies,68 and studies con- cannabis use can be meaningfully linked to stroke. A Downloaded\nducted using outpatient69,70 or inpatient71,72 national data- study of a large longitudinal cohort of Canadian pregnant\nbases or hospital electronic health records73 have been women that included >1 million participants between\nequivocal, depending on the study design, covariates 1989 and 2019 with follow-up at 30 years observed\nfrom\nconsidered in the analysis, and source of the popula- that cannabis use disorder was associated with a dou-\ntion being studied. Inconsistent associations also can be bling of risk for hemorrhagic stroke (hazard ratio, 2.08 http://ahajournals.org\nattributable to the presence of comparison groups and [95% CI, 1.07–4.05]) but no increased risk for ischemic\nwhether adjustment of other important risk factors was or other cerebrovascular disease.74 Because  ...
# (8, 'Testai et al Effect of Marijuana on Brain Health and Cognition\nand the development of atherosclerosis.52 This is in con- Table 2. Key Summary Points\ntrast to the atheroprotective role associated with CB2. CLINICAL\nSection Notes\nAND\nAcute cardiovascular events and stroke also have\nActions of THC disrupts endocannabinoid signaling pathways and\nbeen reported in patients using synthetic cannabinoids.77 Cannabis affects synaptic plasticity. In the short term, this affects the GUIDELINES\nSTATEMENTS\nSpice is associated with idiopathic thrombocytopenic in Animal strength of interneuronal connections; in the long term, it\npurpura, which increases the risk of major hemorrhage.78 Models leads to changes in the functioning of neuronal networks.\nExposure to THC during adolescence can lead to struc-\nIn addition, intracranial hemorrhage in Spice users has\ntural, molecular, and functional alterations of brain circuits,\nbeen linked to the presence of brodifacoum, an adulter- particularly in areas involved in cognition and behavior.\nant considered a superwarfarin.79\nEffect of In preclinical models, THC disrupts the normal signaling\nPrenatal of the endocannabinoid system during development and\nExposure to throughout ontogenesis and results in abnormal neurotrans-\nEDUCATION AND FUTURE DIRECTIONS Cannabinoid mission.\nAgonist Prenatal THC affects neuroanatomic areas associated with\nOur understanding of the ramifications of cannabis con- cognition and emotional regulation, including the PFC,\nsumption on brain health is limited but rapidly evolving. limbic system, and ventral tegmentum of the midbrain.\nObservational studies have produced conflicting results in Effects of Acute intoxication with marijuana affects memory, behavior,\nrelation to the effect of marijuana on different outcomes Marijuana Use and impulsivity.\non Human The long-term effect of cannabis on cognition may be\nof interest, including hypertension, AF, MI, and cognition.\nCognition domain specific.\nSeveral methodological factors may explain these apparent\nNeuroimaging studies have shown structural changes in\ncontradictions. First, given its historical classification as an cannabis users; however, the results are inconsistent.\nillicit drug, the use of marijuana has been underreported for Functional changes may be observed in areas of the brain\ngenerations. The inclusion of marijuana users in the control involved in cognition among cannabis users.\ngroup of observational studies that rely on self-reported use Early exposure to cannabis may have a negative effect on\ncognitive function.\ncould underestimate its effect on brain health. Second, sev-\nEffects of Several studies have described an association between\neral behaviors such as smoking and alcohol use are associ-\nMarijuana cannabis use and increased risk of stroke.\nated with marijuana consumption and can influence stroke Use on Data from population survey studies indicate that the pat-\nrisk and brain connectivity.80,81 The often missing informa- Cerebrovas- tern (heavy vs less) and frequency (>10 d/mo) of cannabis\ntion on frequency of exposure to these factors limits our cular Risk and use may increase the risk of stroke.\nDisease\nability to determine with accuracy the independent effect of Cigarette smoking is common in cannabis users and may\nbe an important modifier or confounder of the relationship\nmarijuana. Third, the time of exposure, frequency of use, and Downloaded\nbetween cannabis use and stroke risk.\nbioavailability of marijuana, which is affected by the route Given the potential role of cannabis as a vasoactive\nof administration, diet, and concomitant use of medications substance and its potential role in cardiac pathology and\nthat may affect its metabolism, are reported inconsistently.10 atherosclerosis development, cannabis use also may\nincrease stroke risk via reversible cerebral vasoconstriction from\nFourth, THC and CBD have different pharmacological syndromes or may ...
# (9, 'Testai et al Effect of Marijuana on Brain Health and Cognition\
ey on\nuse predicts risks of heart failure and cerebrovascular accidents: results Alcohol and Related Conditions-III. Am J Psychiatry. 2016;173:588–599.\nfrom the National Inpatient Sample. J Cardiovasc Med (Hagerstown). doi: 10.1176/appi.ajp.2015.15070907\n2018;19:480–484. doi: 10.2459/JCM.0000000000000681 81. Vergara VM, Weiland BJ, Hutchison KE, Calhoun VD. The impact of com-\n73. San Luis CV, O’Hana S Nobleza C, Shekhar S, Sugg R, Villareal DJ, binations of alcohol, nicotine, and cannabis on dynamic brain connectivity.\nMehta T, Gangadhara S. Association between recent cannabinoid use Neuropsychopharmacology. 2018;43:877–890. doi: 10.1038/npp.2017.280\nand acute ischemic stroke. Neurol Clin Pract. 2020;10:333–339. doi: 82. Brunt TM, van Genugten M, Höner-Snoeken K, van de Velde MJ, Niesink\n10.1212/CPJ.0000000000000888 RJ. Therapeutic satisfaction and subjective effects of different strains of\n74. Auger N, Paradis G, Low N, Ayoub A, He S, Potter BJ. Cannabis use pharmaceutical-grade cannabis. J Clin Psychopharmacol. 2014;34:344–\ndisorder and the future risk of cardiovascular disease in parous women: 349. doi: 10.1097/JCP.0000000000000129\na longitudinal cohort study. BMC Med. 2020;18:328. doi: 10.1186/ 83. Kocis PT, Vrana KE. Delta-9-tetrahydrocannabinol and cannabidiol drug-\ns12916-020-01804-6 drug interactions. Med Cannabis Cannabinoids. 2020;3:61–73. doi:\n75. Jensen J, Leonard J, Salottolo K, McCarthy K, Wagner J, Bar-Or D. 10.1159/000507998\nThe epidemiology of reversible cerebral vasoconstriction syndrome in 84. Wu LT, Zhu H, Swartz MS. Trends in cannabis use disorders among racial/\npatients at a Colorado comprehensive stroke center. J Vasc Interv Neurol. ethnic population groups in the United States. Drug Alcohol Depend.\n2018;10:32–38. 2016;165:181–190. doi: 10.1016/j.drugalcdep.2016.06.00 ...

# %% [markdown]
# ### Step 3. Clean up the text

# %%
def clean_text(pages: List[Tuple[int, str]], cleaning_functions: List[Callable[[str], str]]) -> List[Tuple[int, str]]:
    """
    Cleans the text in a list of pages

    :param pages: The list of pages, each containing both a string of text and a page number.
    :return: The list of pages, each containing both a string of cleaned text and a page number.
    """
    cleaned_pages = []
    for page_num, text in pages:
        for cleaning_function in cleaning_functions:
            text = cleaning_function(text)
        cleaned_pages.append((page_num, text))
    return cleaned_pages

# %%
# Three simple regex cleaning functions

def merge_hyphenated_words(text: str) -> str:
    return re.sub(r"(\w)-\n(\w)", r"\1\2", text)

def fix_newlines(text: str) -> str:
    return re.sub(r"(?<!\n)\n(?!\n)", " ", text)

def remove_multiple_newlines(text: str) -> str:
    return re.sub(r"\n{2,}", "\n", text)

# %%
# These three simple cleaning funcstions are defined below. Here, we're just putting them into a list
cleaning_functions = [
    merge_hyphenated_words,
    fix_newlines,
    remove_multiple_newlines,
    ]

# We call a function defined just below that applies each of the cleaning functions in a list to our text
cleaned_text_pdf = clean_text(raw_pages, cleaning_functions)

# %%
type(cleaned_text_pdf)
# Out:
# list

# %%
len(cleaned_text_pdf)
# Out:
# 12

# %%
for i in cleaned_text_pdf:
    print(i)
# Out:
# (1, 'Stroke AHA SCIENTIFIC STATEMENT Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association The American Academy of Neurology affirms the value of this statement as an educational tool for neurologists. Fernando D. Testai, MD, PhD, Chair; Philip B. Gorelick, MD, MPH, Vice Chair; Hugo J. Aparicio, MD, MPH; Francesca M. Filbey, PhD; Raul Gonzalez, PhD; Rebecca F. Gottesman, MD, PhD; Miriam Melis, PhD; Mariann R. Piano, RN, PhD; Tiziana Rubino, PhD; Sarah Y. Song, MD; on behalf of the American Heart Association Stroke Brain Health Science Subcommittee of the Stroke Council; Council on Arteriosclerosis, Thrombosis and Vascular Biology; Council on Cardiovascular and Stroke Nursing; Council on Lifestyle and Cardiometabolic Health; and Council on Peripheral Vascular Disease ABSTRACT: Marijuana is perceived as a harmless drug, and its recreational use has gained popularity among young individuals. The concentration of active ingredients in recreational formulations has gradually increased over time, and high-potency illicit cannabinomimetics have become available. Thus, the consumption of cannabis in the general population is rising. Data from preclinical models demonstrate that cannabinoid receptors are expressed in high density in areas involved in cognition and behavior, particularly during periods of active neurodevelopment and maturation. In addition, growing evidence highlights the role of endogenous cannabinoid pathways in the regulation of neurotransmitter release, synaptic plasticity, and neurodevelopment. In animal models, exogenous cannabinoids disrupt these important processes and lead to cognitive and Downloaded behavioral abnormalities. These data correlate with the higher risk of cognitive impairment reported in some observational studies done in humans. It is unclear whether the effect of cannabis on cognition reverts after abstinence. However, this evidence, along with the increased risk of stroke reported in marijuana users, raises concerns about its potential long-term effects on cognitive function. This scientific statement reviews the safety of cannabis use from the perspective of brain from health, describes mechanistically how cannabis may cause cognitive dysfunction, and advocates for a more informed health http://ahajournals.org care worker and consumer about the potential for cannabis to adversely affect the brain. Key Words: AHA Scientific Statements ◼ brain ◼ cannabis ◼ cognition ◼ marijuana ◼ stroke by Marijuana, or cannabis, was considered an illicit drug for 11% in 2002 to 18% in 2019.3 The use of marijuana on decades. However, in many parts of the world, can- has gained popularity, particularly among adolescents and July nabis has been legalized for medical use or decrimi- young adults, with ≈36% of 12th graders and 43% of col7, nalized for recreational or medicinal applications. This shift lege students reporting having used it in the past year.4 In 2023 in attitude has resulted in a rapid increase in its use. It has parallel, evidence suggests that the potency of cannabis been estimated that ≈183 million people in the world used products in the United States, measured by the concentramarijuana in 20141 and that 22 million met criteria for can- tion of the primary psychoactive constituent of marijuana, nabis use disorder in 2016.2 In addition, according to the Δ9-tetrahydrocannabinol (THC), has gradually increased 2002 to 2019 National Survey on Drug Use and Health, from ≈4% in 1995 to 15% in 2018.5 the proportion of the US population >12 years of age who Cannabinoid receptors are expressed in high density used marijuana in the past year increased gradually from in areas of the brain involved in executive function and The content is solely the responsibility of the authors and does not necessarily represent the official views of the National Institutes of Health. © 2022 American Heart Association, Inc. Stroke is available at www.ahajournals.org/journal/str  ...
# (2, 'Testai et al Effect of Marijuana on Brain Health and Cognition memory such as the hippocampus, amygdala, and pre- cells. In the periphery, CB1 localizes to sympathetic nerve frontal cortex (PFC), particularly during periods of active terminals and sensory neurons. In the central nervous CLINICAL AND brain development.6 Acute intoxication with cannabinoids system, it is expressed mainly in presynaptic membranes can impair memory and behavioral inhibition.7 Cannabi- of excitatory and inhibitory neurons, where it regulates GUIDELINES STATEMENTS noids also regulate anxiety and can produce psycho- the vesicular release of dopamine, GABA, and glutamate. sis-like effects.6 Evidence shows that age at exposure In comparison, CB2 is expressed mainly in immune cells, may influence the effect of cannabinoids on cognitive including microglia.9 function. For example, the prenatal, perinatal, and ado- CBD is a nonpsychoactive cannabinoid that has antilescent periods may be particularly sensitive to these oxidant and anti-inflammatory properties. It is thought compounds.8 Data obtained in preclinical models have that CBD exerts some of the beneficial effects that shown that cannabis and its associated signaling path- phytocannabinoids have in Dravet syndrome and Lenways regulate neurotransmission and play an active role nox-Gastaut syndrome. Furthermore, studies done in in key cerebral processes, including neuroinflammation, preclinical models suggest that CBD is beneficial in neurogenesis, neural migration, synaptic pruning, and Alzheimer disease, cerebral ischemia, multiple sclerowhite matter development.6,9 Furthermore, experimental sis, and other neurologic disorders.9,14 The therapeutic data show that cannabinoids can regulate the function- potential of CBD is being investigated in different clinical ing of different cytochrome-P450 isoforms and uridine trials. Compared with THC, CBD signals through differ5′-diphospho-glucuronosyltransferases. Thus, there is ent pathways but does not activate CB1 and CB2. At low a potential risk for drug-to-drug interactions with medi- concentration, CBD blocks the orphan G-protein–coucations commonly used by the elderly such as warfarin, pled receptor-55, the equilibrative nucleoside transporter antiarrhythmic agents, sedatives, and anticonvulsants.10 1, and the transient receptor potential of melastatin type These factors have raised concerns about the poten- 8 channel. It also activates the serotonin (5-hydroxytryptial effect of cannabis on cognitive vitality. The goal of tamine) 1A receptor, the transient receptor potential of this scientific statement is to critically appraise the safety ankyrin type 1 channel, and α3 and α1 glycine receptors. of cannabis use from the perspective of brain health. At high concentration, CBD activates the nuclear peroxisome proliferator-activated receptor γ and the transient receptor potential of vanilloid types 1 and 2.12,14 CANNABIS AND ENDOCANNABINOIDS Several cannabinoids have received approval in different countries for the treatment of specific medical Downloaded Anandamide and 2-arachidonoyl-glycerol are endogconditions. In addition, high-potency synthetic cannaenous bioactive lipids that activate 2 G-protein–coupled bimimetics such as Spice are available in the illegal marreceptors designated as cannabinoid receptor type 1 ket (Table 1).15–17 (CB1) and 2 (CB2). These lipids, called endocannabi- from noids, are not stored in vesicles but are synthesized on http://ahajournals.org demand. The system formed by the cannabinoid recep- NEUROBIOLOGICAL ACTIONS OF tors CB1 and CB2, endogenous ligands, and enzymes CANNABIS IN ANIMAL MODELS involved in their production and degradation is known as the endocannabinoid system (ECS). A detailed descrip- Molecular and cellular mechanisms underlying the tion of the composition and regulation of the ECS is effects of cannabis on the developing brain are inferred beyond the scope of this publication; this topic has been mai ...
# (3, 'Testai et al Effect of Marijuana on Brain Health and Cognition Table 1. Synthetic and Semisynthetic Cannabinoids CB1 receptors located on GABAergic interneurons, which represent nearly three-quarters of the brain CB1 STNEMETATS Cannabinoid Active SENILEDIUG type ingredient Indication receptors, and astrocytes, resulting in the release of hippocampal glutamate. Concomitantly, THC affects Medical15,16 the transmission of other neurotransmitters involved Cesamet Nabilone Treatment of refractory cancer che- (synthetic THC motherapy–associated nausea and in the modulation of memory such as acetylcholine, LACINILC DNA analog) vomiting*† adenosine, and serotonin.19,20 Furthermore, THC activaMarinol (pill) Dronabinol (syn- Anorexia with weight loss in patients tion of CB1 receptors present on mitochondria leads to thetic THC) with AIDS or cancer*† decreased cellular respiration and ATP supply.19 ATP is Syndros Dronabinol (syn- Treatment of refractory cancer che- fundamental in maintaining and regulating neurotrans- (solution) thetic THC) motherapy–associated nausea and mission, and its reduction might contribute to THCvomiting*† induced cognitive deficits. Epidiolex Purified CBD Seizures associated with LennoxGastaut syndrome and Dravet syn- Repeated exposure to cannabis, especially during drome in patients >1 y of age* the adolescent developmental period, may be especially Seizures associated with tuberous scle- harmful to brain health and cause structural, molecular, rosis complex in patients >1 y of age* and functional alterations of brain circuits, particularly in Sativex Nabiximols Adjunctive therapy for symptomatic the PFC and hippocampus.8,21,22 Long-term THC expo- (extract of treatment of refractory spasticity in THC, CBD, adult patients with multiple sclerosis sure induces CB1 receptor downregulation and desenand other minor indication† sitization that appear more intense and widespread after cannabinoids, Adjunctive treatment for symptomatic adolescent exposure as opposed to adulthood expoterpenoids, and neuropathy in adult patients with mulflavonoids) tiple sclerosis indication† sure.22 Data obtained in experimental models showed that these effects could have implications for neurodeAdjunctive treatment for patients with advanced cancer with refractory severe velopmental processes in which the ECS plays a role. pain indication† Accordingly, long-term THC exposure during adolesIllicit17 cence may disrupt dynamic changes occurring in glutaK2, Spice, Originally synthesized to study the matergic and GABAergic systems, leading to excessive Kronic, endocannabinoid system synaptic pruning (ie, loss of synaptic contacts), long-term Kaos Bind cannabinoid receptors with high dysfunction in prefrontal excitatory/inhibitory balance, affinity and can cause hallucinations, and desynchronization of PFC neuronal networks, which Downloaded agitation, psychosis, short-term memory loss, seizures, coagulopathy, and myo- also dysregulate the mesolimbic dopaminergic pathway cardial infarction (Figure).23 These changes may represent the molecular CBD indicates cannabidiol; and THC, Δ9-tetrahydrocannabinol. underpinnings of cognitive deficits and altered emotional from *Approved by the US Food and Drug Administration. reactivity and social behavior observed long after ado- †Approved by the Health Products and Food Branch of Health Canada. lescent long-term THC exposure.22 Long-term changes http://ahajournals.org Animal models have been used to examine the role of in brain functionality induced by THC exposure during the ECS in the modulation of synaptic plasticity, a pro- adolescence might also arise from epigenetic modificacess that allows the brain to change and adapt to new tions with a marked reprogramming of the transcriptome, information.18 The ECS modulates synaptic plasticity by affecting mainly genes related to synaptic plasticity proaffecting the strength of interneuronal connections and, cesses.8,19 These effects have not been repo ...
# (4, 'Testai et al Effect of Marijuana on Brain Health and Cognition CLINICAL AND GUIDELINES STATEMENTS Figure. Effect of Δ9-tetrahydrocannabinol (THC) on different neurobiological processes. The effect of THC on the brain constitutes a continuum throughout the lifetime of an individual. However, 2 windows of brain vulnerability have been identified in preclinical models. The colored boxes represent the different processes that have been demonstrated to be affected on exposure to THC during these sensitive developmental periods. PFC indicates prefrontal cortex. THC in models of heavy cannabis use in middle adoles- information, have been observed in these neuroanatomic Downloaded cence. However, even lower doses may produce these areas (Figure).8,24,27–30 Aberrant glutamatergic function same effects when administered earlier in adolescence.22 is a common hallmark, as indexed by changes in the expression and function of ionotropic and metabotropic from receptors and in dynamic regulation of glutamate levEFFECT OF PRENATAL EXPOSURE TO els by glutamate transporters at both synaptic cleft and http://ahajournals.org CANNABINOID AGONISTS extrasynaptic spaces. These changes depend largely on A recent study examined associations between prenatal the alterations of endocannabinoid signaling pathways cannabis exposure (PCE) and various indicators of mental caused by exogenous cannabinoids during development and neurocognitive health in a sample of 11 489 youth.26 and throughout ontogenesis (eg, neural proliferation, Self-report of maternal cannabis use during pregnancy survival, directional axonal growth).8,24,27–30 Defects in was associated with various adverse outcomes among ECS function also may account for the interneuronop- by youth at 9 to 10 years of age, including poorer perfor- athy observed in many brain regions of PCE offspring, on July mance on tests of neurocognitive functioning and total a phenomenon often more prominent in female than in intracranial volumes, even after controlling for potential male animals.8,27–29 In the PFC, this persistent inhibitory 7, 2023 confounders. Several reviews describe PCE sequelae circuit deficit also is associated with a delayed switch of in preclinical models.8,24,27–30 Here, we focus on mecha- GABA from its excitatory role early in development to a nistic insights inferred from animal studies recapitulat- classic inhibitory function exerted throughout the central ing the neuropsychiatric features of clinical outcomes.31 nervous system later in life.8,29 This is particularly relevant The detrimental effect of PCE on cognitive process- because the GABA switch represents a critical milestone ing and emotional regulation of the progeny has been during neurodevelopment. Any alteration in the normal ascribed to changes in intrinsic and synaptic properties and predictable temporal sequence of these periods and plasticity of cortical (eg, PFC), limbic (eg, amygdala, such as delays, stalls, or accelerations imposed by PCE hippocampus), and midbrain (eg, ventral tegmentum) may lead to perturbations of offspring cognitive processregions. Changes in the balance of excitatory and inhibi- ing and emotional behavior.8,29 tory input strength, along with alterations in how principal It was observed that marijuana use leads to dysreguneurons and interneurons receive, integrate, and convey lation of monoaminergic pathways and stress response Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396 April 2022 e179')
# (5, 'Testai et al Effect of Marijuana on Brain Health and Cognition systems.8,27–29 PCE hampers the maturation of mono- with more specific domains affected,36 albeit with smaller amines, which also exert trophic actions on target neurons effect size compared with that found by Lovell et al.35 STNEMETATS SENILEDIUG and afferent terminals. This phenomenon may depend on Both lacked support for worse neurocognition in early epigenetic modifications and may be implicated in aber- adolescence in that neither found that age at onset of rant reward signaling. Furthermore, PCE is associated cannabis use influenced the association between expowith an endophenotype in the offspring, which displays sure and cognitive performance. LACINILC DNA protracted dysregulation of stress responsivity that is In contrast to these meta-analyses, large longitunot explained by glucocorticoid levels. A susceptibility dinal studies provide stronger causal inferences by to acute and chronic stress is tied to many psychiatric examining change over time. In the CARDIA study disorders, ranging from depressed mood and psycho- (Coronary Artery Risk Development in Young Adults), sis to substance use disorders and anxiety. A deeper 3385 participants 18 to 30 years of age were followed understanding of how PCE interferes with endocannabi- up longitudinally. Marijuana use was assessed perinoid signaling during neurodevelopment would allow us odically in the 25-year follow-up. In addition, cognitive to explore potential interventions aimed at restoring or assessment was completed 25 years after inception. In reprogramming the hierarchical progression of develop- this study, cumulative years of exposure to marijuana mental milestones. was associated with worse verbal memory (0.13 lower SD in the verbal memory test for each additional 5 years of exposure to marijuana).37 Longitudinal co-twin EFFECTS OF MARIJUANA USE ON HUMAN studies use a research design that additionally controls for shared variance from genetic and environmental COGNITION factors. Two large longitudinal twin studies (n=3066) Acute intoxication from marijuana is associated with with neurocognitive measures collected before (at impairment of working and episodic memory, behavioral 9–12 years of age) and after (17–20 years of age) disinhibition, and impulsivity, which can affect perfor- cannabis exposure reported that declines in vocabulary mance in real-world activities.6 For example, a meta-anal- and general knowledge were associated with being a ysis from 2016 showed that the odds of being involved cannabis user but not with amount of cannabis conin a motor vehicle accident was increased 36% in can- sumed.38 Twins discordant for cannabis use showed no nabis users relative to nonusers.32 In addition, a crossover differences in IQ declines. Thus, differences were likely clinical trial published in 2020 investigated the effect of caused by shared risk factors. Using a similar design, Downloaded different cannabis products in relation to on-road driving Meier et al39 reported that lower IQ predated cannatests. The SD of lateral position, a measure of lane weav- bis use with no evidence of actual IQ declines among ing, swerving, and overcorrection, was 20.29 cm at 40 to 1989 twins assessed at 5, 12, and 18 years of age. from 100 minutes after inhalation of THC-dominant cannabis Ross et al40 evaluated other aspects of neurocogniand 21.09 cm after inhalation of a mixture of THC and tion among 856 individual twins and reported only 1 http://ahajournals.org CBD. It is interesting to note that the SD of lateral posi- within-family effect of 70 tested. Specifically, frequency tion after inhalation of CBD-dominant cannabis was sim- of cannabis use at 17 years of age was associated with ilar to that in the placebo group (18.21 cm versus 18.26 poorer executive functioning at 23 years of age, but cm).33 These observations illustrate the differential short- executive functioning problems predating cannabis use term ...
# (6, 'Testai et al Effect of Marijuana on Brain Health and Cognition large twin samples from the United States (n=474) and EFFECTS OF MARIJUANA USE ON Australia (n=622), cannabis use was unrelated to vol- CLINICAL CEREBROVASCULAR RISK AND DISEASE AND umes of the thalamus, caudate nucleus, putamen, pallidum, hippocampus, amygdala, and nucleus accumbens.43 Cerebrovascular Risk Factors GUIDELINES STATEMENTS A multisite study of cortical surface measures (n=262) Similar to the literature linking marijuana use with cardioreported no difference in cortical thickness, surface area, vascular outcomes,10 evidence that marijuana consumpand gyrification index in cannabis users versus nonus- tion increases the prevalence of specific cerebrovascular ers, in cannabis dependence versus nondependence risk factors and disease is limited by a preponderance versus nonusers, and in early adolescent versus late of observational studies, cross-sectional studies, case adolescent onset of cannabis use versus nonuse.44 Thus, reports, and case series prone to potential publication brain structural abnormalities related to cannabis use are and other biases. Postulated adverse effects of mariinconsistent. juana use may include sympathetic nervous system actiFunctional MRI studies report more robust effects, vation, blood pressure changes, platelet activation, and particularly after prolonged cannabis use. A meta-analy- electrophysiological effects.50–52 Concomitant tobacco sis of task-based functional MRI studies in current adult smoking and other substance use and abuse possibly and adolescent users found abnormalities in activation contribute to these effects, which may be short term and in both age groups. Relative to nonusing control sub- have been studied mostly in low-risk populations such jects, adult cannabis users had greater brain activation as younger adults. These factors may explain why many in the superior (seed-based d mapping [SDM-Z], 1.561; longitudinal studies linking marijuana use and cardiovasP<0.002) and posterior (SDM-Z, 1.479; P<0.003) trans- cular or metabolic risk factors have been negative after verse temporal and inferior frontal gyri (SDM-Z, 1.568; multivariable adjustment for unhealthy behaviors such as P<0.002) and less activation in the striatum (SDM-Z, diet and tobacco smoking.53–55 −1.843; P<0.001), insula (SDM-Z, −1.637; P<0.001), Hypertension, in particular, is an important risk factor and middle frontal gyrus across different tasks. Adoles- for ischemic stroke, hemorrhagic stroke, and subarachcent cannabis users also had greater activation in the noid hemorrhage. With marijuana use, the most common inferior parietal gyrus (SDM-Z, 1.06; P<0.001) and puta- acute reaction in humans is a decrease in blood pressure men (SDM-Z, 1.008; P<0.001) compared with nonusers resulting from cannabinoid effects on the vasculature and across various tasks, suggesting compensatory neuro- autonomic nervous system.52 Despite this physiological adaptive mechanisms.45 These functional abnormalities reaction, limited studies using the National Health and Downloaded persist despite cessation of cannabis use and beyond Nutrition Examination Survey showed a modest assothe period when THC metabolites are detectable. A ciation of recent cannabis use with higher systolic blood meta-analysis of the same adolescent studies found that pressure and higher prevalence of hypertension among from >25-day abstinent adolescent cannabis users exhibited current users 30 to 59 years of age.56 Heavy users, greater activation in the right inferior frontal gyrus in defined as use of marijuana or hashish in >20 of the http://ahajournals.org addition to other areas relevant for executive functioning past 30 days, had higher odds of abnormal blood presand self-regulatory mechanisms.46 sure compared with never-users. Although this difference Several recent studies examined cannabis effects in remained statistically significant after adjustment for populations with prem ...
# (7, 'Testai et al Effect of Marijuana on Brain Health and Cognition the Coronary Artery Risk Development in Young Adults that when no cannabis use was compared with heavy study, cumulative or recent marijuana use was not asso- cannabis use in the past year, cannabis use was associ- STNEMETATS SENILEDIUG ciated with coronary heart disease, stroke, or cardiovas- ated with an increased risk for the occurrence of nonfatal cular disease mortality.61 This finding contrasts with a stroke and transient ischemic attack.70 Similarly, another population-based, multi-institutional database study that study found that recent (within the past 30 days) and observed an increased risk of 3-year cumulative inci- frequent (>10 d/mo) cannabis use was associated with LACINILC DNA dence of MI among marijuana users compared with con- increased risk for the occurrence of stroke compared trol subjects (1.37% vs 0.54%; relative risk, 2.54 [95% with nonuse, whereas less frequent cannabis use (≤10 CI, 2.45–2.61]).62 d/mo or less than weekly in the past year) was not assoSimilarly, marijuana use appears to be a trigger for AF. ciated with increased risk.69,70 Data from the Nationwide Inpatient Sample show that the Using several International Classification of Diseases, percentage of individuals with cannabis use disorder dis- Ninth Revision, Clinical Modification codes for marijuana use, charged in the postlegalization period (2010–2014) with a Nationwide Inpatient Sample study found that cannabis the diagnosis of arrhythmia increased 31%.63 However, in use among men and women hospitalized between 2004 a study of patients hospitalized for heart failure, marijuana and 2011 was associated with a 17% increased relative risk users had a reduced odds of AF compared with nonusers for acute ischemic stroke in a multivariable-adjusted analy- (adjusted odds ratio, 0.87 [95% CI, 0.77–0.98]).50 Simul- sis. Concomitant use of tobacco with cannabis increased taneous use of cocaine, stimulants, and other drugs may the risk to 31%.71 Similarly, a separate study using the be responsible for observations of AF among marijuana Nationwide Inpatient Sample but between 2009 and 2010 users, although this remains to be fully studied outside of observed a higher odds of stroke among cannabis users observational and cross-sectional reports. (odds ratio, 1.24 [95% CI, 1.14–1.34]).72 In contrast, investigators using electronic health record data from patients admitted to a single center between 2015 and 2017 found Risk of Stroke and Transient Ischemic Attack that testing positive for cannabis use was not associated Several case reports and case series mostly in young with the risk of ischemic stroke compared with testing individuals suggest a relationship between recent and negative, even after adjustment for numerous confounders, heavy cannabis use and risk of stroke.64–66 In contrast, including age, cigarette smoking, and comorbidities.73 and as reviewed below, findings among case-control There may be certain populations or scenarios in which studies,67 population-based studies,68 and studies con- cannabis use can be meaningfully linked to stroke. A Downloaded ducted using outpatient69,70 or inpatient71,72 national data- study of a large longitudinal cohort of Canadian pregnant bases or hospital electronic health records73 have been women that included >1 million participants between equivocal, depending on the study design, covariates 1989 and 2019 with follow-up at 30 years observed from considered in the analysis, and source of the popula- that cannabis use disorder was associated with a doution being studied. Inconsistent associations also can be bling of risk for hemorrhagic stroke (hazard ratio, 2.08 http://ahajournals.org attributable to the presence of comparison groups and [95% CI, 1.07–4.05]) but no increased risk for ischemic whether adjustment of other important risk factors was or other cerebrovascular disease.74 Because of the theconsidered, along with attention to  ...
# (8, 'Testai et al Effect of Marijuana on Brain Health and Cognition and the development of atherosclerosis.52 This is in con- Table 2. Key Summary Points trast to the atheroprotective role associated with CB2. CLINICAL Section Notes AND Acute cardiovascular events and stroke also have Actions of THC disrupts endocannabinoid signaling pathways and been reported in patients using synthetic cannabinoids.77 Cannabis affects synaptic plasticity. In the short term, this affects the GUIDELINES STATEMENTS Spice is associated with idiopathic thrombocytopenic in Animal strength of interneuronal connections; in the long term, it purpura, which increases the risk of major hemorrhage.78 Models leads to changes in the functioning of neuronal networks. Exposure to THC during adolescence can lead to strucIn addition, intracranial hemorrhage in Spice users has tural, molecular, and functional alterations of brain circuits, been linked to the presence of brodifacoum, an adulter- particularly in areas involved in cognition and behavior. ant considered a superwarfarin.79 Effect of In preclinical models, THC disrupts the normal signaling Prenatal of the endocannabinoid system during development and Exposure to throughout ontogenesis and results in abnormal neurotransEDUCATION AND FUTURE DIRECTIONS Cannabinoid mission. Agonist Prenatal THC affects neuroanatomic areas associated with Our understanding of the ramifications of cannabis con- cognition and emotional regulation, including the PFC, sumption on brain health is limited but rapidly evolving. limbic system, and ventral tegmentum of the midbrain. Observational studies have produced conflicting results in Effects of Acute intoxication with marijuana affects memory, behavior, relation to the effect of marijuana on different outcomes Marijuana Use and impulsivity. on Human The long-term effect of cannabis on cognition may be of interest, including hypertension, AF, MI, and cognition. Cognition domain specific. Several methodological factors may explain these apparent Neuroimaging studies have shown structural changes in contradictions. First, given its historical classification as an cannabis users; however, the results are inconsistent. illicit drug, the use of marijuana has been underreported for Functional changes may be observed in areas of the brain generations. The inclusion of marijuana users in the control involved in cognition among cannabis users. group of observational studies that rely on self-reported use Early exposure to cannabis may have a negative effect on cognitive function. could underestimate its effect on brain health. Second, sevEffects of Several studies have described an association between eral behaviors such as smoking and alcohol use are associMarijuana cannabis use and increased risk of stroke. ated with marijuana consumption and can influence stroke Use on Data from population survey studies indicate that the patrisk and brain connectivity.80,81 The often missing informa- Cerebrovas- tern (heavy vs less) and frequency (>10 d/mo) of cannabis tion on frequency of exposure to these factors limits our cular Risk and use may increase the risk of stroke. Disease ability to determine with accuracy the independent effect of Cigarette smoking is common in cannabis users and may be an important modifier or confounder of the relationship marijuana. Third, the time of exposure, frequency of use, and Downloaded between cannabis use and stroke risk. bioavailability of marijuana, which is affected by the route Given the potential role of cannabis as a vasoactive of administration, diet, and concomitant use of medications substance and its potential role in cardiac pathology and that may affect its metabolism, are reported inconsistently.10 atherosclerosis development, cannabis use also may increase stroke risk via reversible cerebral vasoconstriction from Fourth, THC and CBD have different pharmacological syndromes or may indirectly increase stroke risk. effects. Although the use o ...
# (9, 'Testai et al Effect of Marijuana on Brain Health and Cognition marijuana resolve completely after months of abstinence. marijuana users and to review their medications to idenHowever, the disruption of endocannabinoid signaling tify potential drug-to-drug interactions. Knowledgeable STNEMETATS SENILEDIUG pathways during the prenatal and perinatal periods and health care professionals will be able to properly eduin adolescence may be detrimental to neurodevelop- cate potential or active marijuana users about its possible ment.6,8,9 Key points discussed in this scientific statement adverse effects, empowering them to make an informed are summarized in Table 2. It should be noted that the decision that is based on unbiased data. LACINILC DNA overarching goal of this scientific statement was to discuss mechanisms by which marijuana use could influence brain health. However, as the field is developing, several ARTICLE INFORMATION important aspects require additional research. As an The American Heart Association makes every effort to avoid any actual or potenexample, there is limited information comparing the dif- tial conflicts of interest that may arise as a result of an outside relationship or a personal, professional, or business interest of a member of the writing panel. Speferential effect of recreational, illicit, and medicinal uses cifically, all members of the writing group are required to complete and submit a of marijuana, as well as the type of cannabis product con- Disclosure Questionnaire showing all such relationships that might be perceived sumed. Similarly, the modulatory effects of social determi- as real or potential conflicts of interest. This statement was approved by the American Heart Association Science nants of health and race and ethnicity on the interaction Advisory and Coordinating Committee on July 29, 2021, and the American Heart of brain health and marijuana use are largely unexplored. Association Executive Committee on September 5, 2021. A copy of the document The latter area of research may be particularly important is available at https://professional.heart.org/statements by using either “Search for Guidelines & Statements” or the “Browse by Topic” area. To purchase additional because communities of color in the United States may reprints, call 215-356-2721 or email Meredith.Edelman@wolterskluwer.com. be disproportionately affected by natural and synthetic The American Heart Association requests that this document be cited as folcannabinoids in relation to use and exposure and the lows: Testai FD, Gorelick PB, Aparicio HJ, Filbey FM, Gonzalez R, Gottesman RF, Melis M, Piano MR, Rubino T, Song SY; on behalf of the American Heart Associalegal implications of criminalization of marijuana.84 tion Stroke Brain Health Science Subcommittee of the Stroke Council; Council on Public health efforts should be considered to raise Arteriosclerosis, Thrombosis and Vascular Biology; Council on Cardiovascular and awareness about the potential negative effects associ- Stroke Nursing; Council on Lifestyle and Cardiometabolic Health; and Council on Peripheral Vascular Disease. Use of marijuana: effect on brain health
risk of stroke: evidence from a general population survey. Aust 0000000000000485 N Z J Public Health. 2016;40:226–230. doi: 10.1111/1753-6405.12477 79. Kelkar AH, Smith NA, Martial A, Moole H, Tarantino MD, Roberts JC. An out71. Rumalla K, Reddy AY, Mittal MK. Recreational marijuana use and break of synthetic cannabinoid–associated coagulopathy in Illinois. N Engl J acute ischemic stroke: a population-based analysis of hospitalized Med. 2018;379:1216–1223. doi: 10.1056/NEJMoa1807652 patients in the United States. J Neurol Sci. 2016;364:191–196. doi: 80. Hasin DS, Kerridge BT, Saha TD, Huang B, Pickering R, Smith SM, Jung 10.1016/j.jns.2016.01.066 J, Zhang H, Grant BF. Prevalence and correlates of DSM-5 cannabis use 72. Kalla A, Krishnamoorthy PM, Gopalakrishnan A, Figueredo VM. Cannabis disorder, 2012-2013: findings from the National Epidemiologic Survey on use predicts risks of heart failure and cerebrovascular accidents: results Alcohol and Related Conditions-III. Am J Psychiatry. 2016;173:588–599. from the National Inpatient Sample. J Cardiovasc Med (Hagerstown). doi: 10.1176/appi.ajp.2015.15070907 2018;19:480–484. doi: 10.2459/JCM.0000000000000681 81. Vergara VM, Weiland BJ, Hutchison KE, Calhoun VD. The impact of com73. San Luis CV, O’Hana S Nobleza C, Shekhar S, Sugg R, Villareal DJ, binations of alcohol, nicotine, and cannabis on dynamic brain connectivity. Mehta T, Gangadhara S. Association between recent cannabinoid use Neuropsychopharmacology. 2018;43:877–890. doi: 10.1038/npp.2017.280 and acute ischemic stroke. Neurol Clin Pract. 2020;10:333–339. doi: 82. Brunt TM, van Genugten M, Höner-Snoeken K, van de Velde MJ, Niesink 10.1212/CPJ.0000000000000888 RJ. Therapeutic satisfaction and subjective effects of different strains of 74. Auger N, Paradis G, Low N, Ayoub A, He S, Potter BJ. Cannabis use pharmaceutical-grade cannabis. J Clin Psychopharmacol. 2014;34:344– disorder and the future risk of cardiovascular disease in parous women: 349. doi: 10.1097/JCP.0000000000000129 a longitudinal cohort study. BMC Med. 2020;18:328. doi: 10.1186/ 83. Kocis PT, Vrana KE. Delta-9-tetrahydrocannabinol and cannabidiol drugs12916-020-01804-6 drug interactions. Med Cannabis Cannabinoids. 2020;3:61–73. doi: 75. Jensen J, Leonard J, Salottolo K, McCarthy K, Wagner J, Bar-Or D. 10.1159/000507998 The epidemiology of reversible cerebral vasoconstriction syndrome in 84. Wu LT, Zhu H, Swartz MS. Trends in cannabis use disorders among racial/ patients at a Colorado comprehensive stroke center. J Vasc Interv Neurol. ethnic population groups in the United States. Drug Alcohol Depend. 2018;10:32–38. 2016;165:181–190. doi: 10.1016/j.drugalcdep.2016.06.002 Downloaded from http://ahajournals. ...

# %% [markdown]
# ### Step 4. Create text chunks from each page, preserving page number and metadata as well as chunk number

# %%
def text_to_docs(text: List[str], metadata: Dict[str, str]) -> List[Document]:
    """
    Converts list of strings to a list of chunks with metadata.
    
    :param text: A list of strings
    :param metadata: A dictionary of meta data
    """
    doc_chunks = []

    for page_num, page in text:
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""],
            chunk_overlap=200,
        )
        chunks = text_splitter.split_text(page)
        for i, chunk in enumerate(chunks):
            doc = Document(
                page_content=chunk,
                metadata={
                    "page_number": page_num,
                    "chunk": i,
                    "source": f"p{page_num}-{i}",
                    **metadata,
                },
            )
            doc_chunks.append(doc)

    return doc_chunks

# %%
# We split the pages into overlapping chunks using the text_to_docs function
document_chunks = text_to_docs(cleaned_text_pdf, metadata)

# %%
type(document_chunks)
# Out:
# list

# %%
# We have more chunks than we did pages
len(document_chunks)
# Out:
# 94

# %%
# Notice that the meta data is still attached to each chunk: page_number, chunk, source, title, author, creation date
for i in document_chunks:
    print(i)
    print("")
# Out:
# page_content='Stroke AHA SCIENTIFIC STATEMENT Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association The American Academy of Neurology affirms the value of this statement as an educational tool for neurologists. Fernando D. Testai, MD, PhD, Chair; Philip B. Gorelick, MD, MPH, Vice Chair; Hugo J. Aparicio, MD, MPH; Francesca M. Filbey, PhD; Raul Gonzalez, PhD; Rebecca F. Gottesman, MD, PhD; Miriam Melis, PhD; Mariann R. Piano, RN, PhD; Tiziana Rubino, PhD; Sarah Y. Song, MD; on behalf of the American Heart Association Stroke Brain Health Science Subcommittee of the Stroke Council; Council on Arteriosclerosis, Thrombosis and Vascular Biology; Council on Cardiovascular and Stroke Nursing; Council on Lifestyle and Cardiometabolic Health; and Council on Peripheral Vascular Disease ABSTRACT: Marijuana is perceived as a harmless drug, and its recreational use has gained popularity among young individuals. The concentration of active ingredients in recreational' metadata={'page_number': 1, 'chunk': 0, 'source': 'p1-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='l Vascular Disease ABSTRACT: Marijuana is perceived as a harmless drug, and its recreational use has gained popularity among young individuals. The concentration of active ingredients in recreational formulations has gradually increased over time, and high-potency illicit cannabinomimetics have become available. Thus, the consumption of cannabis in the general population is rising. Data from preclinical models demonstrate that cannabinoid receptors are expressed in high density in areas involved in cognition and behavior, particularly during periods of active neurodevelopment and maturation. In addition, growing evidence highlights the role of endogenous cannabinoid pathways in the regulation of neurotransmitter release, synaptic plasticity, and neurodevelopment. In animal models, exogenous cannabinoids disrupt these important processes and lead to cognitive and Downloaded behavioral abnormalities. These data correlate with the higher risk of cognitive impairment reported in some obser' metadata={'page_number': 1, 'chunk': 1, 'source': 'p1-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='s cannabinoids disrupt these important processes and lead to cognitive and Downloaded behavioral abnormalities. These data correlate with the higher risk of cognitive impairment reported in some observational studies done in humans. It is unclear whether the effect of cannabis on cognition reverts after abstinence. However, this evidence, along with the increased risk of stroke reported in marijuana users, raises concerns about its potential long-term effects on cognitive function. This scientific statement reviews the safety of cannabis use from the perspective of brain from health, describes mechanistically how cannabis may cause cognitive dysfunction, and advocates for a more informed health http://ahajournals.org care worker and consumer about the potential for cannabis to adversely affect the brain. Key Words: AHA Scientific Statements ◼ brain ◼ cannabis ◼ cognition ◼ marijuana ◼ stroke by Marijuana, or cannabis, was considered an illicit drug for 11% in 2002 to 18% in 2019.3 The' metadata={'page_number': 1, 'chunk': 2, 'source': 'p1-2', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='fect the brain. Key Words: AHA Scientific Statements ◼ brain ◼ cannabis ◼ cognition ◼ marijuana ◼ stroke by Marijuana, or cannabis, was considered an illicit drug for 11% in 2002 to 18% in 2019.3 The use of marijuana on decades. However, in many parts of the world, can- has gained popularity, particularly among adolescents and July nabis has been legalized for medical use or decrimi- young adults, with ≈36% of 12th graders and 43% of col7, nalized for recreational or medicinal applications. This shift lege students reporting having used it in the past year.4 In 2023 in attitude has resulted in a rapid increase in its use. It has parallel, evidence suggests that the potency of cannabis been estimated that ≈183 million people in the world used products in the United States, measured by the concentramarijuana in 20141 and that 22 million met criteria for can- tion of the primary psychoactive constituent of marijuana, nabis use disorder in 2016.2 In addition, according to the Δ9-tetrahydro' metadata={'page_number': 1, 'chunk': 3, 'source': 'p1-3', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='oncentramarijuana in 20141 and that 22 million met criteria for can- tion of the primary psychoactive constituent of marijuana, nabis use disorder in 2016.2 In addition, according to the Δ9-tetrahydrocannabinol (THC), has gradually increased 2002 to 2019 National Survey on Drug Use and Health, from ≈4% in 1995 to 15% in 2018.5 the proportion of the US population >12 years of age who Cannabinoid receptors are expressed in high density used marijuana in the past year increased gradually from in areas of the brain involved in executive function and The content is solely the responsibility of the authors and does not necessarily represent the official views of the National Institutes of Health. © 2022 American Heart Association, Inc. Stroke is available at www.ahajournals.org/journal/str e176 April 2022 Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396' metadata={'page_number': 1, 'chunk': 4, 'source': 'p1-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='Testai et al Effect of Marijuana on Brain Health and Cognition memory such as the hippocampus, amygdala, and pre- cells. In the periphery, CB1 localizes to sympathetic nerve frontal cortex (PFC), particularly during periods of active terminals and sensory neurons. In the central nervous CLINICAL AND brain development.6 Acute intoxication with cannabinoids system, it is expressed mainly in presynaptic membranes can impair memory and behavioral inhibition.7 Cannabi- of excitatory and inhibitory neurons, where it regulates GUIDELINES STATEMENTS noids also regulate anxiety and can produce psycho- the vesicular release of dopamine, GABA, and glutamate. sis-like effects.6 Evidence shows that age at exposure In comparison, CB2 is expressed mainly in immune cells, may influence the effect of cannabinoids on cognitive including microglia.9 function. For example, the prenatal, perinatal, and ado- CBD is a nonpsychoactive cannabinoid that has antilescent periods may be particularly sensitive to t' metadata={'page_number': 2, 'chunk': 0, 'source': 'p2-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='binoids on cognitive including microglia.9 function. For example, the prenatal, perinatal, and ado- CBD is a nonpsychoactive cannabinoid that has antilescent periods may be particularly sensitive to these oxidant and anti-inflammatory properties. It is thought compounds.8 Data obtained in preclinical models have that CBD exerts some of the beneficial effects that shown that cannabis and its associated signaling path- phytocannabinoids have in Dravet syndrome and Lenways regulate neurotransmission and play an active role nox-Gastaut syndrome. Furthermore, studies done in in key cerebral processes, including neuroinflammation, preclinical models suggest that CBD is beneficial in neurogenesis, neural migration, synaptic pruning, and Alzheimer disease, cerebral ischemia, multiple sclerowhite matter development.6,9 Furthermore, experimental sis, and other neurologic disorders.9,14 The therapeutic data show that cannabinoids can regulate the function- potential of CBD is being investigated i' metadata={'page_number': 2, 'chunk': 1, 'source': 'p2-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='atter development.6,9 Furthermore, experimental sis, and other neurologic disorders.9,14 The therapeutic data show that cannabinoids can regulate the function- potential of CBD is being investigated in different clinical ing of different cytochrome-P450 isoforms and uridine trials. Compared with THC, CBD signals through differ5′-diphospho-glucuronosyltransferases. Thus, there is ent pathways but does not activate CB1 and CB2. At low a potential risk for drug-to-drug interactions with medi- concentration, CBD blocks the orphan G-protein–coucations commonly used by the elderly such as warfarin, pled receptor-55, the equilibrative nucleoside transporter antiarrhythmic agents, sedatives, and anticonvulsants.10 1, and the transient receptor potential of melastatin type These factors have raised concerns about the poten- 8 channel. It also activates the serotonin (5-hydroxytryptial effect of cannabis on cognitive vitality. The goal of tamine) 1A receptor, the transient receptor potential of' metadata={'page_number': 2, 'chunk': 2, 'source': 'p2-2', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='concerns about the poten- 8 channel. It also activates the serotonin (5-hydroxytryptial effect of cannabis on cognitive vitality. The goal of tamine) 1A receptor, the transient receptor potential of this scientific statement is to critically appraise the safety ankyrin type 1 channel, and α3 and α1 glycine receptors. of cannabis use from the perspective of brain health. At high concentration, CBD activates the nuclear peroxisome proliferator-activated receptor γ and the transient receptor potential of vanilloid types 1 and 2.12,14 CANNABIS AND ENDOCANNABINOIDS Several cannabinoids have received approval in different countries for the treatment of specific medical Downloaded Anandamide and 2-arachidonoyl-glycerol are endogconditions. In addition, high-potency synthetic cannaenous bioactive lipids that activate 2 G-protein–coupled bimimetics such as Spice are available in the illegal marreceptors designated as cannabinoid receptor type 1 ket (Table 1).15–17 (CB1) and 2 (CB2). These lipi' metadata={'page_number': 2, 'chunk': 3, 'source': 'p2-3', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='lipids that activate 2 G-protein–coupled bimimetics such as Spice are available in the illegal marreceptors designated as cannabinoid receptor type 1 ket (Table 1).15–17 (CB1) and 2 (CB2). These lipids, called endocannabi- from noids, are not stored in vesicles but are synthesized on http://ahajournals.org demand. The system formed by the cannabinoid recep- NEUROBIOLOGICAL ACTIONS OF tors CB1 and CB2, endogenous ligands, and enzymes CANNABIS IN ANIMAL MODELS involved in their production and degradation is known as the endocannabinoid system (ECS). A detailed descrip- Molecular and cellular mechanisms underlying the tion of the composition and regulation of the ECS is effects of cannabis on the developing brain are inferred beyond the scope of this publication; this topic has been mainly from preclinical studies that permit controlling by reviewed extensively elsewhere.9,11,12 for social and environmental factors that could influ- on Phytocannabinoids are exogenous cannabinoids ence ou' metadata={'page_number': 2, 'chunk': 4, 'source': 'p2-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='rom preclinical studies that permit controlling by reviewed extensively elsewhere.9,11,12 for social and environmental factors that could influ- on Phytocannabinoids are exogenous cannabinoids ence outcomes of interest. In addition, animal models July extracted from flowering plants from the cannabis genus, allow the investigation of a range of human age-related 7, including Cannabis sativa, Cannabis indica, and Cannabis behavioral factors (eg, novelty and sensation seek- 2023 ruderalis. Whether these are species or subspecies is ing, impulsivity, risk-taking behaviors) and key stages a matter of debate. More than 100 phytocannabinoids of neurodevelopment that are conserved across many have been extracted from these plants, with THC and mammalian species. However, many individual (eg, specannabidiol (CBD) being the most abundant. The rela- cies, strain, age) and experimental (eg, design, drug, tive concentration of THC and CBD in these strains is dose, delivery, regimen) variables, alo' metadata={'page_number': 2, 'chunk': 5, 'source': 'p2-5', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='annabidiol (CBD) being the most abundant. The rela- cies, strain, age) and experimental (eg, design, drug, tive concentration of THC and CBD in these strains is dose, delivery, regimen) variables, along with objective variable. In general, cannabis cultivars can be classified end points (eg, behavioral paradigm, experimental techaccording to the cannabinoid produced as chemotype nique), have contributed to equivocal findings across I (THC rich), II (THC/CBD balanced), III (CBD rich), IV studies. Nonetheless, experimental animal models (cannabigerol rich), or V (cannabinoid free).13 of prenatal and adolescent cannabis exposure have THC is a psychoactive alkaloid that signals through proved fundamental in disclosing the underlying neuroCB1 and CB2 receptors. Cannabinoid receptor type 1 biological mechanisms that might explain several cliniis expressed abundantly in peripheral and central neural cal neuropsychiatric outcomes outlined here. Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.00000' metadata={'page_number': 2, 'chunk': 6, 'source': 'p2-6', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='gical mechanisms that might explain several cliniis expressed abundantly in peripheral and central neural cal neuropsychiatric outcomes outlined here. Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396 April 2022 e177' metadata={'page_number': 2, 'chunk': 7, 'source': 'p2-7', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='Testai et al Effect of Marijuana on Brain Health and Cognition Table 1. Synthetic and Semisynthetic Cannabinoids CB1 receptors located on GABAergic interneurons, which represent nearly three-quarters of the brain CB1 STNEMETATS Cannabinoid Active SENILEDIUG type ingredient Indication receptors, and astrocytes, resulting in the release of hippocampal glutamate. Concomitantly, THC affects Medical15,16 the transmission of other neurotransmitters involved Cesamet Nabilone Treatment of refractory cancer che- (synthetic THC motherapy–associated nausea and in the modulation of memory such as acetylcholine, LACINILC DNA analog) vomiting*† adenosine, and serotonin.19,20 Furthermore, THC activaMarinol (pill) Dronabinol (syn- Anorexia with weight loss in patients tion of CB1 receptors present on mitochondria leads to thetic THC) with AIDS or cancer*† decreased cellular respiration and ATP supply.19 ATP is Syndros Dronabinol (syn- Treatment of refractory cancer che- fundamental in maintaining and' metadata={'page_number': 3, 'chunk': 0, 'source': 'p3-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='chondria leads to thetic THC) with AIDS or cancer*† decreased cellular respiration and ATP supply.19 ATP is Syndros Dronabinol (syn- Treatment of refractory cancer che- fundamental in maintaining and regulating neurotrans- (solution) thetic THC) motherapy–associated nausea and mission, and its reduction might contribute to THCvomiting*† induced cognitive deficits. Epidiolex Purified CBD Seizures associated with LennoxGastaut syndrome and Dravet syn- Repeated exposure to cannabis, especially during drome in patients >1 y of age* the adolescent developmental period, may be especially Seizures associated with tuberous scle- harmful to brain health and cause structural, molecular, rosis complex in patients >1 y of age* and functional alterations of brain circuits, particularly in Sativex Nabiximols Adjunctive therapy for symptomatic the PFC and hippocampus.8,21,22 Long-term THC expo- (extract of treatment of refractory spasticity in THC, CBD, adult patients with multiple sclerosis sure ind' metadata={'page_number': 3, 'chunk': 1, 'source': 'p3-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='imols Adjunctive therapy for symptomatic the PFC and hippocampus.8,21,22 Long-term THC expo- (extract of treatment of refractory spasticity in THC, CBD, adult patients with multiple sclerosis sure induces CB1 receptor downregulation and desenand other minor indication† sitization that appear more intense and widespread after cannabinoids, Adjunctive treatment for symptomatic adolescent exposure as opposed to adulthood expoterpenoids, and neuropathy in adult patients with mulflavonoids) tiple sclerosis indication† sure.22 Data obtained in experimental models showed that these effects could have implications for neurodeAdjunctive treatment for patients with advanced cancer with refractory severe velopmental processes in which the ECS plays a role. pain indication† Accordingly, long-term THC exposure during adolesIllicit17 cence may disrupt dynamic changes occurring in glutaK2, Spice, Originally synthesized to study the matergic and GABAergic systems, leading to excessive Kronic, endocann' metadata={'page_number': 3, 'chunk': 2, 'source': 'p3-2', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='exposure during adolesIllicit17 cence may disrupt dynamic changes occurring in glutaK2, Spice, Originally synthesized to study the matergic and GABAergic systems, leading to excessive Kronic, endocannabinoid system synaptic pruning (ie, loss of synaptic contacts), long-term Kaos Bind cannabinoid receptors with high dysfunction in prefrontal excitatory/inhibitory balance, affinity and can cause hallucinations, and desynchronization of PFC neuronal networks, which Downloaded agitation, psychosis, short-term memory loss, seizures, coagulopathy, and myo- also dysregulate the mesolimbic dopaminergic pathway cardial infarction (Figure).23 These changes may represent the molecular CBD indicates cannabidiol; and THC, Δ9-tetrahydrocannabinol. underpinnings of cognitive deficits and altered emotional from *Approved by the US Food and Drug Administration. reactivity and social behavior observed long after ado- †Approved by the Health Products and Food Branch of Health Canada. lescent long-term TH' metadata={'page_number': 3, 'chunk': 3, 'source': 'p3-3', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='l from *Approved by the US Food and Drug Administration. reactivity and social behavior observed long after ado- †Approved by the Health Products and Food Branch of Health Canada. lescent long-term THC exposure.22 Long-term changes http://ahajournals.org Animal models have been used to examine the role of in brain functionality induced by THC exposure during the ECS in the modulation of synaptic plasticity, a pro- adolescence might also arise from epigenetic modificacess that allows the brain to change and adapt to new tions with a marked reprogramming of the transcriptome, information.18 The ECS modulates synaptic plasticity by affecting mainly genes related to synaptic plasticity proaffecting the strength of interneuronal connections and, cesses.8,19 These effects have not been reported after ultimately, the functioning of neuronal networks. From adult THC exposure.19 by on the mechanistic standpoint, THC activates cannabinoid In addition to the effects on neuron cellular and subJuly' metadata={'page_number': 3, 'chunk': 4, 'source': 'p3-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='after ultimately, the functioning of neuronal networks. From adult THC exposure.19 by on the mechanistic standpoint, THC activates cannabinoid In addition to the effects on neuron cellular and subJuly receptors in the brain, thus interfering with physiological cellular components, recent evidence suggests that actions of endocannabinoids. Spatial and time resolution alterations in glial cells have a key role in the actions of 7, 2023 of endocannabinoid production is pivotal for correct pro- THC.24 Long-term THC exposure activates microglia and cessing of different brain functions such as higher-order astrocytes to produce inflammatory cytokines. For examcognition, memory, reward, mood, and stress sensitiv- ple, long-term administration of THC during adolescence ity.8,19,20 Consequently, THC, activating nonspecifically increased the microglial expression of the proinflammaCB1 receptors in the brain, disrupts the fine-tuning of tory mediators tumor necrosis factor-α, inducible nitric syn' metadata={'page_number': 3, 'chunk': 5, 'source': 'p3-5', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='C, activating nonspecifically increased the microglial expression of the proinflammaCB1 receptors in the brain, disrupts the fine-tuning of tory mediators tumor necrosis factor-α, inducible nitric synaptic activity exerted by endocannabinoids, even- oxide synthase, and cyclooxygenase-2 by 60%, 130%, tually impairing connectivity of neuronal networks and and 80%, respectively, and reduced the expression of brain functionality. the anti-inflammatory cytokine interleukin-10 by 30% in Although incompletely understood, the way in which the PFC. The resulting neuroinflammatory response was THC disrupts memory and learning may be through associated with memory impairment during adulthood.25 its differential effect on neurotransmitter release and Dose constitutes an additional important variable to binding to CB1 receptors.19 For example, THC activates consider. Most studies describe detrimental effects of e178 April 2022 Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396' metadata={'page_number': 3, 'chunk': 6, 'source': 'p3-6', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='Testai et al Effect of Marijuana on Brain Health and Cognition CLINICAL AND GUIDELINES STATEMENTS Figure. Effect of Δ9-tetrahydrocannabinol (THC) on different neurobiological processes. The effect of THC on the brain constitutes a continuum throughout the lifetime of an individual. However, 2 windows of brain vulnerability have been identified in preclinical models. The colored boxes represent the different processes that have been demonstrated to be affected on exposure to THC during these sensitive developmental periods. PFC indicates prefrontal cortex. THC in models of heavy cannabis use in middle adoles- information, have been observed in these neuroanatomic Downloaded cence. However, even lower doses may produce these areas (Figure).8,24,27–30 Aberrant glutamatergic function same effects when administered earlier in adolescence.22 is a common hallmark, as indexed by changes in the expression and function of ionotropic and metabotropic from receptors and in dynamic regulation of gl' metadata={'page_number': 4, 'chunk': 0, 'source': 'p4-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='cts when administered earlier in adolescence.22 is a common hallmark, as indexed by changes in the expression and function of ionotropic and metabotropic from receptors and in dynamic regulation of glutamate levEFFECT OF PRENATAL EXPOSURE TO els by glutamate transporters at both synaptic cleft and http://ahajournals.org CANNABINOID AGONISTS extrasynaptic spaces. These changes depend largely on A recent study examined associations between prenatal the alterations of endocannabinoid signaling pathways cannabis exposure (PCE) and various indicators of mental caused by exogenous cannabinoids during development and neurocognitive health in a sample of 11 489 youth.26 and throughout ontogenesis (eg, neural proliferation, Self-report of maternal cannabis use during pregnancy survival, directional axonal growth).8,24,27–30 Defects in was associated with various adverse outcomes among ECS function also may account for the interneuronop- by youth at 9 to 10 years of age, including poorer perfor-' metadata={'page_number': 4, 'chunk': 1, 'source': 'p4-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='axonal growth).8,24,27–30 Defects in was associated with various adverse outcomes among ECS function also may account for the interneuronop- by youth at 9 to 10 years of age, including poorer perfor- athy observed in many brain regions of PCE offspring, on July mance on tests of neurocognitive functioning and total a phenomenon often more prominent in female than in intracranial volumes, even after controlling for potential male animals.8,27–29 In the PFC, this persistent inhibitory 7, 2023 confounders. Several reviews describe PCE sequelae circuit deficit also is associated with a delayed switch of in preclinical models.8,24,27–30 Here, we focus on mecha- GABA from its excitatory role early in development to a nistic insights inferred from animal studies recapitulat- classic inhibitory function exerted throughout the central ing the neuropsychiatric features of clinical outcomes.31 nervous system later in life.8,29 This is particularly relevant The detrimental effect of PCE on cognit' metadata={'page_number': 4, 'chunk': 2, 'source': 'p4-2', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='unction exerted throughout the central ing the neuropsychiatric features of clinical outcomes.31 nervous system later in life.8,29 This is particularly relevant The detrimental effect of PCE on cognitive process- because the GABA switch represents a critical milestone ing and emotional regulation of the progeny has been during neurodevelopment. Any alteration in the normal ascribed to changes in intrinsic and synaptic properties and predictable temporal sequence of these periods and plasticity of cortical (eg, PFC), limbic (eg, amygdala, such as delays, stalls, or accelerations imposed by PCE hippocampus), and midbrain (eg, ventral tegmentum) may lead to perturbations of offspring cognitive processregions. Changes in the balance of excitatory and inhibi- ing and emotional behavior.8,29 tory input strength, along with alterations in how principal It was observed that marijuana use leads to dysreguneurons and interneurons receive, integrate, and convey lation of monoaminergic pathways an' metadata={'page_number': 4, 'chunk': 3, 'source': 'p4-3', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='y input strength, along with alterations in how principal It was observed that marijuana use leads to dysreguneurons and interneurons receive, integrate, and convey lation of monoaminergic pathways and stress response Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396 April 2022 e179' metadata={'page_number': 4, 'chunk': 4, 'source': 'p4-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='Testai et al Effect of Marijuana on Brain Health and Cognition systems.8,27–29 PCE hampers the maturation of mono- with more specific domains affected,36 albeit with smaller amines, which also exert trophic actions on target neurons effect size compared with that found by Lovell et al.35 STNEMETATS SENILEDIUG and afferent terminals. This phenomenon may depend on Both lacked support for worse neurocognition in early epigenetic modifications and may be implicated in aber- adolescence in that neither found that age at onset of rant reward signaling. Furthermore, PCE is associated cannabis use influenced the association between expowith an endophenotype in the offspring, which displays sure and cognitive performance. LACINILC DNA protracted dysregulation of stress responsivity that is In contrast to these meta-analyses, large longitunot explained by glucocorticoid levels. A susceptibility dinal studies provide stronger causal inferences by to acute and chronic stress is tied to many psychi' metadata={'page_number': 5, 'chunk': 0, 'source': 'p5-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='ast to these meta-analyses, large longitunot explained by glucocorticoid levels. A susceptibility dinal studies provide stronger causal inferences by to acute and chronic stress is tied to many psychiatric examining change over time. In the CARDIA study disorders, ranging from depressed mood and psycho- (Coronary Artery Risk Development in Young Adults), sis to substance use disorders and anxiety. A deeper 3385 participants 18 to 30 years of age were followed understanding of how PCE interferes with endocannabi- up longitudinally. Marijuana use was assessed perinoid signaling during neurodevelopment would allow us odically in the 25-year follow-up. In addition, cognitive to explore potential interventions aimed at restoring or assessment was completed 25 years after inception. In reprogramming the hierarchical progression of develop- this study, cumulative years of exposure to marijuana mental milestones. was associated with worse verbal memory (0.13 lower SD in the verbal memory test' metadata={'page_number': 5, 'chunk': 1, 'source': 'p5-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='ming the hierarchical progression of develop- this study, cumulative years of exposure to marijuana mental milestones. was associated with worse verbal memory (0.13 lower SD in the verbal memory test for each additional 5 years of exposure to marijuana).37 Longitudinal co-twin EFFECTS OF MARIJUANA USE ON HUMAN studies use a research design that additionally controls for shared variance from genetic and environmental COGNITION factors. Two large longitudinal twin studies (n=3066) Acute intoxication from marijuana is associated with with neurocognitive measures collected before (at impairment of working and episodic memory, behavioral 9–12 years of age) and after (17–20 years of age) disinhibition, and impulsivity, which can affect perfor- cannabis exposure reported that declines in vocabulary mance in real-world activities.6 For example, a meta-anal- and general knowledge were associated with being a ysis from 2016 showed that the odds of being involved cannabis user but not with amount' metadata={'page_number': 5, 'chunk': 2, 'source': 'p5-2', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='ry mance in real-world activities.6 For example, a meta-anal- and general knowledge were associated with being a ysis from 2016 showed that the odds of being involved cannabis user but not with amount of cannabis conin a motor vehicle accident was increased 36% in can- sumed.38 Twins discordant for cannabis use showed no nabis users relative to nonusers.32 In addition, a crossover differences in IQ declines. Thus, differences were likely clinical trial published in 2020 investigated the effect of caused by shared risk factors. Using a similar design, Downloaded different cannabis products in relation to on-road driving Meier et al39 reported that lower IQ predated cannatests. The SD of lateral position, a measure of lane weav- bis use with no evidence of actual IQ declines among ing, swerving, and overcorrection, was 20.29 cm at 40 to 1989 twins assessed at 5, 12, and 18 years of age. from 100 minutes after inhalation of THC-dominant cannabis Ross et al40 evaluated other aspects of neu' metadata={'page_number': 5, 'chunk': 3, 'source': 'p5-3', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='ing, and overcorrection, was 20.29 cm at 40 to 1989 twins assessed at 5, 12, and 18 years of age. from 100 minutes after inhalation of THC-dominant cannabis Ross et al40 evaluated other aspects of neurocogniand 21.09 cm after inhalation of a mixture of THC and tion among 856 individual twins and reported only 1 http://ahajournals.org CBD. It is interesting to note that the SD of lateral posi- within-family effect of 70 tested. Specifically, frequency tion after inhalation of CBD-dominant cannabis was sim- of cannabis use at 17 years of age was associated with ilar to that in the placebo group (18.21 cm versus 18.26 poorer executive functioning at 23 years of age, but cm).33 These observations illustrate the differential short- executive functioning problems predating cannabis use term effect of THC and CBD on cognition. Evidence also could not be ruled out. suggests that the short-term effects of cannabinoids are Magnetic resonance imaging (MRI) techniques dem- by on transient and can' metadata={'page_number': 5, 'chunk': 4, 'source': 'p5-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='ct of THC and CBD on cognition. Evidence also could not be ruled out. suggests that the short-term effects of cannabinoids are Magnetic resonance imaging (MRI) techniques dem- by on transient and can be influenced by the development of onstrate differential associations of cannabis use with July tolerance and the use of other drugs. brain structure and function. In terms of brain structure, The long-term effect of cannabis on cognition, how- alterations related to cannabis use have been mixed. In 7, 2023 ever, is less well established. Recent meta-analyses a longitudinal study including 1598 MRIs done in adoreport residual effects of cannabis use on neurocogni- lescents at baseline and the 5-year follow-up, a dosetion, consistent with prior research.34 A meta-analysis by dependent association was observed between cannabis Lovell et al35 in 2020 focused on adult near-daily can- use and PFC thinning.41 On the other hand, although a nabis use for >2 years and found global neurocognition m' metadata={'page_number': 5, 'chunk': 5, 'source': 'p5-5', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='ion was observed between cannabis Lovell et al35 in 2020 focused on adult near-daily can- use and PFC thinning.41 On the other hand, although a nabis use for >2 years and found global neurocognition meta-analysis found that regular cannabis consumpamong users (n=849) to be about one-quarter of an tion was associated with smaller hippocampal (stanSD worse than that of nonusers (n=764). Four of the 7 dardized mean difference, 0.14 [95% CI, 0.02–0.27]), domains investigated (decision-making, verbal learning, medial orbitofrontal cortex (standardized mean differretention, executive function) showed significant effect ence, 0.30 [95% CI, 0.15–0.45]), and lateral orbitofronsizes ranging from Hedges g=−0.52 to −0.18. A meta- tal cortex (standardized mean difference, 0.19 [95% CI, analysis of cannabis users <26 years of age (n=2152) 0.07–0.32]) volumes relative to nonuse, brain volumes and nonusers (n=6575) also showed a one-quarter of an were not associated with cannabis use duration and dosS' metadata={'page_number': 5, 'chunk': 6, 'source': 'p5-6', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='abis users <26 years of age (n=2152) 0.07–0.32]) volumes relative to nonuse, brain volumes and nonusers (n=6575) also showed a one-quarter of an were not associated with cannabis use duration and dosSD difference in global neurocognitive performance but age.42 Other large studies have reported null effects. In 2 e180 April 2022 Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396' metadata={'page_number': 5, 'chunk': 7, 'source': 'p5-7', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='Testai et al Effect of Marijuana on Brain Health and Cognition large twin samples from the United States (n=474) and EFFECTS OF MARIJUANA USE ON Australia (n=622), cannabis use was unrelated to vol- CLINICAL CEREBROVASCULAR RISK AND DISEASE AND umes of the thalamus, caudate nucleus, putamen, pallidum, hippocampus, amygdala, and nucleus accumbens.43 Cerebrovascular Risk Factors GUIDELINES STATEMENTS A multisite study of cortical surface measures (n=262) Similar to the literature linking marijuana use with cardioreported no difference in cortical thickness, surface area, vascular outcomes,10 evidence that marijuana consumpand gyrification index in cannabis users versus nonus- tion increases the prevalence of specific cerebrovascular ers, in cannabis dependence versus nondependence risk factors and disease is limited by a preponderance versus nonusers, and in early adolescent versus late of observational studies, cross-sectional studies, case adolescent onset of cannabis use versus nonuse' metadata={'page_number': 6, 'chunk': 0, 'source': 'p6-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='rs and disease is limited by a preponderance versus nonusers, and in early adolescent versus late of observational studies, cross-sectional studies, case adolescent onset of cannabis use versus nonuse.44 Thus, reports, and case series prone to potential publication brain structural abnormalities related to cannabis use are and other biases. Postulated adverse effects of mariinconsistent. juana use may include sympathetic nervous system actiFunctional MRI studies report more robust effects, vation, blood pressure changes, platelet activation, and particularly after prolonged cannabis use. A meta-analy- electrophysiological effects.50–52 Concomitant tobacco sis of task-based functional MRI studies in current adult smoking and other substance use and abuse possibly and adolescent users found abnormalities in activation contribute to these effects, which may be short term and in both age groups. Relative to nonusing control sub- have been studied mostly in low-risk populations such jects,' metadata={'page_number': 6, 'chunk': 1, 'source': 'p6-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='abnormalities in activation contribute to these effects, which may be short term and in both age groups. Relative to nonusing control sub- have been studied mostly in low-risk populations such jects, adult cannabis users had greater brain activation as younger adults. These factors may explain why many in the superior (seed-based d mapping [SDM-Z], 1.561; longitudinal studies linking marijuana use and cardiovasP<0.002) and posterior (SDM-Z, 1.479; P<0.003) trans- cular or metabolic risk factors have been negative after verse temporal and inferior frontal gyri (SDM-Z, 1.568; multivariable adjustment for unhealthy behaviors such as P<0.002) and less activation in the striatum (SDM-Z, diet and tobacco smoking.53–55 −1.843; P<0.001), insula (SDM-Z, −1.637; P<0.001), Hypertension, in particular, is an important risk factor and middle frontal gyrus across different tasks. Adoles- for ischemic stroke, hemorrhagic stroke, and subarachcent cannabis users also had greater activation in the noid' metadata={'page_number': 6, 'chunk': 2, 'source': 'p6-2', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content=', is an important risk factor and middle frontal gyrus across different tasks. Adoles- for ischemic stroke, hemorrhagic stroke, and subarachcent cannabis users also had greater activation in the noid hemorrhage. With marijuana use, the most common inferior parietal gyrus (SDM-Z, 1.06; P<0.001) and puta- acute reaction in humans is a decrease in blood pressure men (SDM-Z, 1.008; P<0.001) compared with nonusers resulting from cannabinoid effects on the vasculature and across various tasks, suggesting compensatory neuro- autonomic nervous system.52 Despite this physiological adaptive mechanisms.45 These functional abnormalities reaction, limited studies using the National Health and Downloaded persist despite cessation of cannabis use and beyond Nutrition Examination Survey showed a modest assothe period when THC metabolites are detectable. A ciation of recent cannabis use with higher systolic blood meta-analysis of the same adolescent studies found that pressure and higher prevalence of' metadata={'page_number': 6, 'chunk': 3, 'source': 'p6-3', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='sothe period when THC metabolites are detectable. A ciation of recent cannabis use with higher systolic blood meta-analysis of the same adolescent studies found that pressure and higher prevalence of hypertension among from >25-day abstinent adolescent cannabis users exhibited current users 30 to 59 years of age.56 Heavy users, greater activation in the right inferior frontal gyrus in defined as use of marijuana or hashish in >20 of the http://ahajournals.org addition to other areas relevant for executive functioning past 30 days, had higher odds of abnormal blood presand self-regulatory mechanisms.46 sure compared with never-users. Although this difference Several recent studies examined cannabis effects in remained statistically significant after adjustment for populations with premorbid clinical risk factors and those age, sex, race, ethnicity, body mass index, education, and using medical marijuana. A meta-analysis focused only on survey year, it was no longer statistically signifi' metadata={'page_number': 6, 'chunk': 4, 'source': 'p6-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='clinical risk factors and those age, sex, race, ethnicity, body mass index, education, and using medical marijuana. A meta-analysis focused only on survey year, it was no longer statistically significant after cannabis users with psychosis <25 years of age (n=529) additional adjustment for current tobacco and binge alco- by on and nonusing control subjects with psychosis (n=901). hol use (adjusted odds ratio, 1.47 [95% CI, 0.99–2.16]).57 July In this study, there were significant differences in 3 of 11 The relationship between marijuana use and elevated domains assessed (premorbid IQ, Hedges g=0.40 [stan- blood pressure, especially among heavy users, may drive 7, 2023 dardized effect size]; current IQ, Hedges g=−0.17; work- longer-term associations with cerebrovascular outcomes, ing memory, Hedges g=−0.76).47 Among a sample of although this mechanism remains to be studied. 215 adult patients with chronic pain provided daily herbal Prior cardiovascular disease such as myocardial infarc' metadata={'page_number': 6, 'chunk': 5, 'source': 'p6-5', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='y, Hedges g=−0.76).47 Among a sample of although this mechanism remains to be studied. 215 adult patients with chronic pain provided daily herbal Prior cardiovascular disease such as myocardial infarccannabis containing 12.5% THC for 1 year, no significant tion (MI) or atrial fibrillation (AF) is also an important risk neurocognitive differences were found compared with 216 factor for stroke.58 Case reports of MI after marijuana control subjects.48 This is in line with a study of patients use are mainly among young adults who lack vascular with multiple sclerosis in response to oral dronabinol that risk factors, with onset of MI shortly after use.59 Risk of found no significant differences in MRI-derived measures, MI was elevated 4.8-fold within an hour after smoking including annual percentage of brain volume change and marijuana compared with periods of nonuse. This assooccurrence of new lesions, after 12 months of use.49 These ciation demonstrates the potential role of marijuana as' metadata={'page_number': 6, 'chunk': 6, 'source': 'p6-6', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# ...
#
# page_content='d meta-analysis. JAMA Psychiatry. 2018;75:585– ciations between marijuana use and cardiovascular risk factors and out595. doi: 10.1001/jamapsychiatry.2018.0335 comes: a systematic review. Ann Intern Med. 2018;168:187–194. doi: 37. Auer R, Vittinghoff E, Yaffe K, Künzi A, Kertesz SG, Levine DA, Albanese 10.7326/M17-1548 E, Whitmer RA, Jacobs DR Jr, Sidney S, et al. Association between lifetime 56. Alshaarawy O, Elbaz HA
 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='oi: 10.1097/ADM.0000000000000326 use in adolescent and adult brains: a meta-analysis of fMRI studies. Neuro- 66. Šimůnek L, Krajina A, Herzig R, Vališ M. Cerebral infarction in young marisci Biobehav Rev. 2018;88:26–41. doi: 10.1016/j.neubiorev.2018.03.008 juana smokers: case reports. Acta Medica (Hradec Kralove). 2018;61:74–77. 46. Blest-Hopley G, Giampietro V, Bhattacharyya S. Regular cannabis use is doi: 10.14712/18059694.2018.56 associated with altered activation of central executive and default mode 67. Barber PA, Pridmore HM, Krishnamurthy V, Roberts S, Spriggs DA, networks even after prolonged abstinence in adolescent users: results from Carter KN, Anderson NE. Cannabis, ischemic stroke, and transient ischa complementary meta-analysis. Neurosci Biobehav Rev. 2019;96:45–55. emic attack: a case-control study. Stroke. 2013;44:2327–2329. doi: doi: 10.1016/j.neubiorev.2018.10.026 10.1161/STROKEAHA.113.001562 e186 April 2022 Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396' metadata={'page_number': 11, 'chunk': 11, 'source': 'p11-11', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='Testai et al Effect of Marijuana on Brain Health and Cognition 68. Falkstedt D, Wolff V, Allebeck P, Hemmingsson T, Danielsson AK. Canna- 76. Wolff V, Armspach JP, Beaujeux R, Manisor M, Rouyer O, Lauer V, Meyer bis, tobacco, alcohol use, and the risk of early stroke: a population-based N, Marescaux C, Geny B. High frequency of intracranial arterial steno- CLINICAL cohort study of 45 000 Swedish men. Stroke. 2017;48:265–270. doi: sis and cannabis use in ischaemic stroke in the young. Cerebrovasc Dis. AND 10.1161/STROKEAHA.116.015565 2014;37:438–443. doi: 10.1159/000363618 69. Parekh T, Pemmasani S, Desai R. Marijuana use among young adults 77. Wolff V, Jouanjus E. Strokes are possible complications of cannabinoids use. GUIDELINES (18-44 years of age) and risk of stroke: a Behavioral Risk Factor Surveil- Epilepsy Behav. 2017;70(pt B):355–363. doi: 10.1016/j.yebeh.2017.01.031 STATEMENTS lance System Survey analysis. Stroke. 2020;51:308–310. doi: 10.1161/ 78. Castaneira G, Rojas K, Galili' metadata={'page_number': 12, 'chunk': 0, 'source': 'p12-0', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='actor Surveil- Epilepsy Behav. 2017;70(pt B):355–363. doi: 10.1016/j.yebeh.2017.01.031 STATEMENTS lance System Survey analysis. Stroke. 2020;51:308–310. doi: 10.1161/ 78. Castaneira G, Rojas K, Galili Y, Field Z, Perez-Perez A, Madruga M, STROKEAHA.119.027828 Carlan SJ. Idiopathic thrombocytopenic purpura induced by synthetic 70. Hemachandra D, McKetin R, Cherbuin N, Anstey KJ. Heavy cannabis users cannabinoid. J Addict Med. 2019;13:235–236. doi: 10.1097/ADM. at elevated risk of stroke: evidence from a general population survey. Aust 0000000000000485 N Z J Public Health. 2016;40:226–230. doi: 10.1111/1753-6405.12477 79. Kelkar AH, Smith NA, Martial A, Moole H, Tarantino MD, Roberts JC. An out71. Rumalla K, Reddy AY, Mittal MK. Recreational marijuana use and break of synthetic cannabinoid–associated coagulopathy in Illinois. N Engl J acute ischemic stroke: a population-based analysis of hospitalized Med. 2018;379:1216–1223. doi: 10.1056/NEJMoa1807652 patients in the United States. J Neu' metadata={'page_number': 12, 'chunk': 1, 'source': 'p12-1', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}
#
# page_content='
Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396 April 2022 e187' metadata={'page_number': 12, 'chunk': 4, 'source': 'p12-4', 'title': 'Use of Marijuana: Effect on Brain Health: A Scientific Statement From the American Heart Association', 'author': '', 'creation_date': "D:20220321130727+05'30'"}

# %% [markdown]
# We've seen how steps 2-4 work on a single document. Let's now do it for all the documents in the corpus at once. So far, we haven't done anything with OpenAI's APIs, so redoing the first document as part of a larger iterative function won't cost us anything more in that way.

# %%
# Only work on .pdf files
pdf_file_paths = [file for file in file_paths if file[-4:]=='.pdf']

document_chunks = []
for file in pdf_file_paths:
    print("working on ", file)
    # Step 2: Parse the PDF into pages with page numbers 
    raw_pages, metadata = parse_pdf(file)
    # Step 3: Clean up the text
    cleaning_functions = [
        merge_hyphenated_words,
        fix_newlines,
        remove_multiple_newlines,
    ]
    cleaned_text_pdf = clean_text(raw_pages, cleaning_functions)
    # Step 4: Create text chunks from each page, preserving info
    document_chunks_temp = text_to_docs(cleaned_text_pdf, metadata)
    document_chunks.extend(document_chunks_temp)
print("Done")
print("")
print("The number of total chunks is: ", len(document_chunks))
# Out:
# working on  /Users/esme/Downloads/Project/src/data/marijuana.pdf
# Done
#
# The number of total chunks is:  94

# %% [markdown]
# ### Steps 5&6: Generate embeddings from the chunks, Store the embeddings so they can be accessed by an AI API

# %%
# We specify that we want OpenAI to handle the embeddings, because we'll be referencing them with OpenAI models
embeddings = OpenAIEmbeddings()

# You'll need to change the below folder to match where you want the embeddings to be stored.
embedding_directory = "/Users/esme/Downloads/Project/src/data/chroma"

# Chroma does the hard work for us
vector_store = Chroma.from_documents(
    document_chunks,
    embeddings,
    collection_name = "collection",
    persist_directory = embedding_directory,
)
print(vector_store)
# Out:
# <langchain.vectorstores.chroma.Chroma object at 0x7fa410a8f490>

# %% [markdown]
# ### Step 7: Enter into Q&A with the AI API

# %%
# Specify what model and hyperparameters we want to use
model = ChatOpenAI(
    model_name = "gpt-3.5-turbo",
    temperature = "0",
    verbose = True
)

# Recall what embedding directory to reference
vector_store = Chroma(
    collection_name = "collection",
    embedding_function = embeddings,
    persist_directory = embedding_directory,
)

# Create the "chain" variable that constitutes our actual chat
chain = ConversationalRetrievalChain.from_llm(
    model,
    retriever = vector_store.as_retriever(),
    return_source_documents = True,
    verbose = True,
)

# %%
chat_history = []
question = input("Question: ")
# print(f'chat_history: {chat_history}')
# Generate answer
response = chain({"question": question, "chat_history": chat_history})
# print(response)
# Retrieve answer
answer = response["answer"]
source = response["source_documents"]
# print(f'source: {source}')
print(f'answer: {answer}')
chat_history.append(HumanMessage(content=question))
chat_history.append(AIMessage(content=answer))

# Display answer
# print("\n\nSources:\n")
# for document in source:
#     print(f"Title: {document.metadata['title']}")
#     print(f"Page: {document.metadata['page_number']}")
#     print(f"Text chunk: {document.page_content[:200]}...\n")
# print(f"Answer: {answer}")
# Out:
# Question:  what does your source say about THC?
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the users question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# oncentramarijuana in 20141 and that 22 million met criteria for can- tion of the primary psychoactive constituent of marijuana, nabis use disorder in 2016.2 In addition, according to the Δ9-tetrahydrocannabinol (THC), has gradually increased 2002 to 2019 National Survey on Drug Use and Health, from ≈4% in 1995 to 15% in 2018.5 the proportion of the US population >12 years of age who Cannabinoid receptors are expressed in high density used marijuana in the past year increased gradually from in areas of the brain involved in executive function and The content is solely the responsibility of the authors and does not necessarily represent the official views of the National Institutes of Health. © 2022 American Heart Association, Inc. Stroke is available at www.ahajournals.org/journal/str e176 April 2022 Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396
#
# oncentramarijuana in 20141 and that 22 million met criteria for can- tion of the primary psychoactive constituent of marijuana, nabis use disorder in 2016.2 In addition, according to the Δ9-tetrahydrocannabinol (THC), has gradually increased 2002 to 2019 National Survey on Drug Use and Health, from ≈4% in 1995 to 15% in 2018.5 the proportion of the US population >12 years of age who Cannabinoid receptors are expressed in high density used marijuana in the past year increased gradually from in areas of the brain involved in executive function and The content is solely the responsibility of the authors and does not necessarily represent the official views of the National Institutes of Health. © 2022 American Heart Association, Inc. Stroke is available at www.ahajournals.org/journal/str e176 April 2022 Stroke. 2022;53:e176–e187. DOI: 10.1161/STR.0000000000000396
#
# Testai et al Effect of Marijuana on Brain Health and Cognition and the development of atherosclerosis.52 This is in con- Table 2. Key Summary Points trast to the atheroprotective role associated with CB2. CLINICAL Section Notes AND Acute cardiovascular events and stroke also have Actions of THC disrupts endocannabinoid signaling pathways and been reported in patients using synthetic cannabinoids.77 Cannabis affects synaptic plasticity. In the short term, this affects the GUIDELINES STATEMENTS Spice is associated with idiopathic thrombocytopenic in Animal strength of interneuronal connections; in the long term, it purpura, which increases the risk of major hemorrhage.78 Models leads to changes in the functioning of neuronal networks. Exposure to THC during adolescence can lead to strucIn addition, intracranial hemorrhage in Spice users has tural, molecular, and functional alterations of brain circuits, been linked to the presence of brodifacoum, an adulter- particularly in areas involve
#
# Testai et al Effect of Marijuana on Brain Health and Cognition and the development of atherosclerosis.52 This is in con- Table 2. Key Summary Points trast to the atheroprotective role associated with CB2. CLINICAL Section Notes AND Acute cardiovascular events and stroke also have Actions of THC disrupts endocannabinoid signaling pathways and been reported in patients using synthetic cannabinoids.77 Cannabis affects synaptic plasticity. In the short term, this affects the GUIDELINES STATEMENTS Spice is associated with idiopathic thrombocytopenic in Animal strength of interneuronal connections; in the long term, it purpura, which increases the risk of major hemorrhage.78 Models leads to changes in the functioning of neuronal networks. Exposure to THC during adolescence can lead to strucIn addition, intracranial hemorrhage in Spice users has tural, molecular, and functional alterations of brain circuits, been linked to the presence of brodifacoum, an adulter- particularly in areas involve
# Human: what does your source say about THC?
#
# > Finished chain.
#
# > Finished chain.
# answer: According to the provided sources, THC (Δ9-tetrahydrocannabinol) is the primary psychoactive constituent of marijuana. The sources mention that the use of THC has gradually increased from approximately 4% in 1995 to 15% in 2018 among the US population aged 12 and above. They also state that cannabinoid receptors, which interact with THC, are expressed in high density in areas of the brain involved in executive function and affect synaptic plasticity. The sources suggest that THC disrupts endocannabinoid signaling pathways and affects the strength of interneuronal connections in the short term, leading to changes in the functioning of neuronal networks in the long term. However, it is important to note that the sources do not provide a comprehensive analysis of THC and its effects, so further research may be necessary for a more complete understanding.
